# %%
# !pip install -U pandas-profiling
# Out:
# ...
#      |████████████████████████████████| 256kB 8.2MB/s
# ...
#      |████████████████████████████████| 645kB 15.3MB/s
# ...
#      |████████████████████████████████| 112kB 29.9MB/s
# ...
#      |████████████████████████████████| 3.1MB 18.1MB/s
# ...
#      |████████████████████████████████| 10.1MB 37.1MB/s
# ...
#      |████████████████████████████████| 81kB 9.5MB/s
# ...
#      |████████████████████████████████| 1.1MB 37.4MB/s
# ...
#      |████████████████████████████████| 61kB 7.6MB/s
# ...
#      |████████████████████████████████| 296kB 38.9MB/s
# ...
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-cp37-none-any.whl size=27085 sha256=409356d56ea9a40c844e5a16673291e3a07fd89409e45fbe52f05ec244cb03e3
#   Stored in directory: /root/.cache/pip/wheels/43/07/ac/7c5a9d708d65247ac1f94066cf1db075540b85716c30255459
# ...
#   Created wheel for phik: filename=phik-0.11.2-cp37-none-any.whl size=1107413 sha256=d45ee3e5fdf855f9f11d22736d23820f1f03ee61667fa6fdee94264616367641
# ...

# %%
# !wget https://github.com/BokyungChoi/teaching_in_GrowthHackers/raw/master/Session%2003.%20EDA%20%26%20Data%20Visualization/nyc_citibike.csv
# Out:
# --2021-05-16 12:24:14--  https://github.com/BokyungChoi/teaching_in_GrowthHackers/raw/master/Session%2003.%20EDA%20%26%20Data%20Visualization/nyc_citibike.csv
# Resolving github.com (github.com)... 192.30.255.113
# Connecting to github.com (github.com)|192.30.255.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/BokyungChoi/teaching_in_GrowthHackers/master/Session%2003.%20EDA%20%26%20Data%20Visualization/nyc_citibike.csv [following]
# --2021-05-16 12:24:15--  https://raw.githubusercontent.com/BokyungChoi/teaching_in_GrowthHackers/master/Session%2003.%20EDA%20%26%20Data%20Visualization/nyc_citibike.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11608722 (11M) [text/plain]
# ...

# %%
# !wc nyc_citibike.csv
# Out:
#    72036   726942 11608722 nyc_citibike.csv

# %%
# !head nyc_citibike.csv
# Out:
# start_date,end_date,start_hour,end_hour,trip_duration,start_station_id,start_station_name,start_station_latitude,start_station_longitude,end_station_id,end_station_name,end_station_latitude,end_station_longitude,bike_id,usertype,birth_year,gender,day_since_register
# 2018-05-01,2018-05-01,4,4,390,3002,South End Ave & Liberty St,40.711512,-74.015756,79,Franklin St & W Broadway,40.71911552,-74.00666661,21105,Subscriber,1945,male,36
# 2018-05-01,2018-05-01,1,1,854,3611,Vernon Blvd & 47 Rd,40.7449067,-73.9534573,3572,34 Ave & 38 St,40.756913,-73.921631,32219,Subscriber,1998,male,29
# 2018-05-01,2018-05-01,4,4,526,515,W 43 St & 10 Ave,40.76009437,-73.99461843,388,W 26 St & 10 Ave,40.74971775,-74.00295035,33433,Subscriber,1954,male,55
# 2018-05-01,2018-05-01,3,3,885,3641,Broadway & W 25 St,40.74286877,-73.98918629,336,Sullivan St & Washington Sq,40.73047747,-73.99906065,32028,Subscriber,1963,male,32
# ...

# %%
import pandas as pd
import pandas_profiling
df = pd.read_csv('nyc_citibike.csv',encoding='latin1')

# %%
df
# Out:
#        start_date    end_date  ...  gender  day_since_register
# 0      2018-05-01  2018-05-01  ...    male                  36
# 1      2018-05-01  2018-05-01  ...    male                  29
# 2      2018-05-01  2018-05-01  ...    male                  55
# 3      2018-05-01  2018-05-01  ...    male                  32
# 4      2018-05-01  2018-05-01  ...    male                  34
# ...           ...         ...  ...     ...                 ...
# 72030  2018-05-01  2018-05-01  ...  female                  12
# 72031  2018-05-01  2018-05-01  ...    male                  21
# 72032  2018-05-01  2018-05-01  ...    male                  37
# 72033  2018-05-01  2018-05-01  ...    male                  14
# 72034  2018-05-01  2018-05-01  ...    male                  11
#
# [72035 rows x 18 columns]

# %%
report = df.profile_report()

# %%
report.to_file("report.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
