# %%
# !pip uninstall -y h5py
# !pip install -U h5py==2.10.0
# Out:
# Uninstalling h5py-3.1.0:
#   Successfully uninstalled h5py-3.1.0
# Collecting h5py==2.10.0
#   Downloading https://files.pythonhosted.org/packages/3f/c0/abde58b837e066bca19a3f7332d9d0493521d7dd6b48248451a9e3fe2214/h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 7.6MB/s
# Requirement already satisfied, skipping upgrade: numpy>=1.7 in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.19.5)
# Requirement already satisfied, skipping upgrade: six in /usr/local/lib/python3.7/dist-packages (from h5py==2.10.0) (1.15.0)
# Installing collected packages: h5py
# Successfully installed h5py-2.10.0

# %% [markdown]
# # 모듈 임포팅

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

# %%
import time

# %% [markdown]
# # Keras DNN 최소 코드

# %% [markdown]
# # 데이터 준비
#
# 1차원 데이터 x와 x**2의 1차원 데이타 y

# %%
import numpy as np

x = np.arange(-1,1,0.01)
y = x**2

plt.scatter(x,y)

# %%
print(len(x))
print(x.shape)
# Out:
# 200
# (200,)

# %% [markdown]
# ## 최소 코드
#
# 아래의 코드는 최소 코드.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense, Input

import time


# 모델 정의
model = keras.Sequential()
model.add(Input(1))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


# 컴파일 : 모델 + optimizer + loss
model.compile(optimizer="SGD", loss="mse")


# 학습
model.fit(x, y, epochs=1000, verbose=0, batch_size=20)


# 예측
y_ = model.predict(x)


# 결과 그래프로 보기
plt.scatter(x,y) # 정답
plt.scatter(x,y_,color='r') # 결과
plt.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.

# %% [markdown]
# # Keras DNN 최소 코드에 기본 정도만 추가
#
# 최소는 아니고, 이정도는 매번 사용하는 코드

# %% [markdown]
# ## model.evaluate() - 성능 평가하기

# %%
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense


model = keras.Sequential()
#model.add(Input(1))
model.add(Dense(10, activation='tanh', input_shape=(1,) ))
model.add(Dense(10, activation='tanh' ))
model.add(Dense(1))


#model.compile(optimizer="SGD", loss="mse")
model.compile(optimizer="SGD", loss="mse", metrics=["mae"])


model.fit(x, y, epochs=1000, verbose=0, batch_size=20)

loss, mae = model.evaluate(x, y) # ADD
print("loss=", loss) # ADD
print("mae=", mae) # ADD


y_ = model.predict(x)


plt.scatter(x,y)
plt.scatter(x,y_,color='r')
plt.show()
# Out:
# 200/200 [==============================] - 0s 141us/sample - loss: 0.0015 - mean_absolute_error: 0.0321
# loss= 0.0015133532928302885
# mae= 0.032146633

# %% [markdown]
# 출력에 loss와 mae가 추가되었다.

# %% [markdown]
# ## 테스트셋으로 평가하기
#
# 데이터를 train과 test으로 나누어 준비한다.

# %%
x = np.arange(-1,1,0.01)
np.random.shuffle(x)
y = x**2

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x,train_y)
plt.scatter(test_x,test_y)
plt.show()

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])


# model.fit(x, y, epochs=1000, verbose=0, batch_size=20)
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)


# loss, mae = model.evaluate(x, y)
loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


# y_ = model.predict(x)
y_ = model.predict(test_x)

# plt.scatter(x,y)
plt.scatter(test_x,test_y)
# plt.scatter(x,y_,color='r')
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# 80/80 [==============================] - 0s 321us/sample - loss: 0.0011 - mean_absolute_error: 0.0276
# loss= 0.001065683620981872
# mae= 0.027590822

# %% [markdown]
# train_x, train_y로 학습하였고,
# evaluate()와 predict()에는 test_x, test_y를 사용하였다.
#
# 그려진 그림을 보면 test_x의 점사이에 빈 간격이 보인다. 그 간격이 train_x에 해당한다.

# %% [markdown]
# ## Base Model 결과 저장
#
# 이후 비교를 위해 그래프를 저장해 둔다.

# %%
plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.savefig("base_result.png")

from IPython.display import Image
display(Image("base_result.png"))

# %% [markdown]
# ## 학습 시간을 출력

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])

start_time = time.time() # ADD
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) # ADD 
    

loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# elapsed : 10.769420146942139
# 80/80 [==============================] - 0s 362us/sample - loss: 0.0018 - mean_absolute_error: 0.0341
# loss= 0.001828432409092784
# mae= 0.034132525

# %% [markdown]
# elapsed로 경과된 시간이 초 단위로 보인다.

# %% [markdown]
# ## model.summary() 네트웤 모양 보기

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary() # ADD

start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_13 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_14 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.035868644714355

# %% [markdown]
# 네트웤의 모양이 보인다.
#
# 노드 10개, 10개를 갖는 은닉층 2개가 있다.
#
#
# 모든 레이어는 activation(w\*x+b) 의 형태로,
#
# 첫 번 째 은닉층은 20개( = ((1+1)\*10) = (입력수+1)\*10)의 웨이트를,
#
# 두 번 째 은닉층은 110개( = ( (10+1)\*10) )의 웨이트가 있다..

# %% [markdown]
# # Keras DNN Template
#
# 본 실습에 사용되는 코든 코드의 템플릿.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

import time


# 모델 정의
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


# 모델 컴파일
model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


# 학습
start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))


# 평가
loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


# 예측
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.899994850158691
# 80/80 [==============================] - 0s 464us/sample - loss: 0.0027 - mean_absolute_error: 0.0443
# loss= 0.0027458203490823506
# mae= 0.044273876

# %% [markdown]
# # layer 수

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import time

from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## 히든 레이어를 1개 만

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


# base 모델의 결과
display(Image("base_result.png")) # ADD

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 31
# Trainable params: 31
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 10.3449866771698
# 80/80 [==============================] - 0s 450us/sample - loss: 0.0019 - mean_absolute_error: 0.0312
# loss= 0.0019086630083620549
# mae= 0.031215388

# %% [markdown]
# ## 히든레이어 없을 때

# %%
from tensorflow.keras.layers import Input

model = keras.Sequential()
model.add(Input((1,)))
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


# base 모델의 결과
display(Image("base_result.png")) # ADD

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.53913164138794
# 80/80 [==============================] - 0s 430us/sample - loss: 0.0914 - mean_absolute_error: 0.2698
# loss= 0.09143627136945724
# mae= 0.2698495

# %% [markdown]
# 히든 레이어가 없을 경우 학습되지 않는다.

# %% [markdown]
# ## 히든 레이어를 3개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_21 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_22 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_23 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 251
# Trainable params: 251
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.31222677230835
# 80/80 [==============================] - 0s 512us/sample - loss: 9.3100e-04 - mean_absolute_error: 0.0248
# loss= 0.0009310028748586774
# mae= 0.024799174

# %% [markdown]
# 3개로 증가해도 별 차이 없다.

# %% [markdown]
# ## 히든 레이어를 5개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_25 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_26 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_27 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_28 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_29 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_30 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 471
# Trainable params: 471
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 13.13459300994873
# 80/80 [==============================] - 0s 572us/sample - loss: 0.0011 - mean_absolute_error: 0.0284
# loss= 0.0011193936225026846
# mae= 0.028381746

# %% [markdown]
# 5개로 증가했을 때 살짝 좋은 듯 하다.

# %% [markdown]
# ## 히든 레이어를 10개로

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(10, activation='tanh')) # ADD
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_31 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_32 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_33 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_34 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_35 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_37 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_38 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_39 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_40 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_41 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 1,021
# Trainable params: 1,021
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 14.640312433242798
# 80/80 [==============================] - 0s 813us/sample - loss: 7.2672e-05 - mean_absolute_error: 0.0066
# loss= 7.267204055096954e-05
# mae= 0.0065724542

# %% [markdown]
# 10개로 했을 때 좋아진 차이가 보인다.

# %% [markdown]
# # node 수

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import time

from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

# %% [markdown]
# ## node 수를 작게

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(5, activation='tanh', input_shape=(1,)))
model.add(Dense(5, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_42 (Dense)             (None, 5)                 10
# _________________________________________________________________
# dense_43 (Dense)             (None, 5)                 30
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 6
# =================================================================
# Total params: 46
# Trainable params: 46
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.605504751205444
# 80/80 [==============================] - 0s 811us/sample - loss: 0.0010 - mean_absolute_error: 0.0256
# loss= 0.0010036734165623784
# mae= 0.025594365

# %% [markdown]
# 5개 노드의 경우 살짝 차이가 난다.

# %% [markdown]
# ## 노드 수를 아주 작게

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(2, activation='tanh', input_shape=(1,)))
model.add(Dense(2, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 2)                 4
# _________________________________________________________________
# dense_46 (Dense)             (None, 2)                 6
# _________________________________________________________________
# dense_47 (Dense)             (None, 1)                 3
# =================================================================
# Total params: 13
# Trainable params: 13
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.420063734054565
# 80/80 [==============================] - 0s 690us/sample - loss: 0.0051 - mean_absolute_error: 0.0557
# loss= 0.005126448674127459
# mae= 0.055746935

# %% [markdown]
# 2개의 경우 차이가 커 보인다.

# %% [markdown]
# ## 노드 수가 1개

# %%
model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(1, activation='tanh', input_shape=(1,)))
model.add(Dense(1, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


display(Image("base_result.png"))

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_48 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_49 (Dense)             (None, 1)                 2
# _________________________________________________________________
# dense_50 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 6
# Trainable params: 6
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.215031147003174
# 80/80 [==============================] - 0s 896us/sample - loss: 0.0912 - mean_absolute_error: 0.2697
# loss= 0.09117495119571686
# mae= 0.26967677

# %% [markdown]
# 1개의 경우 거의 학습이 되지 않는다.

# %% [markdown]
# # sin 데이터

# %%
def get_sin_data(start=0, end=10, step=0.1):
  x = np.arange(start,end,step)
  np.random.shuffle(x)
  y = np.sin(x)

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]

  return (train_x, train_y), (test_x, test_y)

# %% [markdown]
# # 학습 추가 진행

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras

import time

from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

# %% [markdown]
# 모델은 그대로 두고 데이터만 sin 데이터로 변경한다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

plt.scatter(train_x,train_y)
plt.show()

plt.scatter(test_x,test_y,color="r")
plt.show()

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_51 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_52 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_53 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 6.688006401062012
# 40/40 [==============================] - 0s 2ms/sample - loss: 0.1866 - mean_absolute_error: 0.3556
# loss= 0.1865641236305237
# mae= 0.3556146

# %% [markdown]
# 학습이 충분히 되지 않은 듯 하다.

# %% [markdown]
# ## 추가 학습

# %%
def fit_one_more(model, train_x, train_y, test_x, test_y, batch_size=20):

  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=batch_size)
  print("elapsed : {}".format(time.time() - start_time))    

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()

def fit_n_times(model, train_x, train_y, test_x, test_y, n):
  
  for i in range(n):
    print("{} times fitting".format(i))
    fit_one_more(model, train_x, train_y, test_x, test_y)

# %%
fit_n_times(model, train_x, train_y, test_x, test_y, 10)
# Out:
# 0 times fitting
# elapsed : 6.25406289100647
# 1 times fitting
# elapsed : 6.107294082641602
# 2 times fitting
# elapsed : 6.163347482681274
# 3 times fitting
# elapsed : 6.256747245788574
# 4 times fitting
# elapsed : 6.1716628074646
# 5 times fitting
# elapsed : 6.2441565990448
# 6 times fitting
# elapsed : 6.925738096237183
# 7 times fitting
# elapsed : 6.174466133117676
# 8 times fitting
# elapsed : 6.1891913414001465
# 9 times fitting
# elapsed : 6.149952173233032

# %% [markdown]
# 학습이 더 진행되면서 거의 완벽하게 학습된 것을 볼 수 있다.

# %% [markdown]
# # model.fit()의 batch_size
#
# batch_size는 GPU와 관련된 옵션이다.
#
# 한번에 GPU에 보내는 데이터의 수이다.
#
# <br>
#
# batch_size가 1일 경우 1개를 보내고, 1개의 결과를 받고, 1번 웨이트를 업데이트 한다.
#
# batch_size가 10일 경우 10개를 보내고, 10개의 결과를 한 번에 받고, 1번 웨이트를 업데이트 한다.
#
# <br>
#
# GPU는 보통 수천개의 코어를 가지고 있다. 동시에 꽤 많은 연산을 처리할 수 있다. 그런데 데이터가 적으면 대부분은 사용하지 못하고 일부만 연산에 사용된다.
#
# 복수의 데이터를 한번에 보내어 한번에 연산을 할수 있고, 그 결과를 반환할 수 있다. 이런 방법으로 연산 시간을 줄일 수 있다.
#
# <br>
#
# 하지만, 복수의 데이터를 한번에 보내는 경우 한번에 보낸 결과가 한번에 오고 1번 업데이트 되면서 업데이트 되는 사항이 뭉개지는 단점이 있다.

# %%
def build_model():

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))

  model.compile(optimizer="SGD", loss="mse", metrics=["mae"])

  return model

def fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes):

  for batch_size in batch_sizes:
    model = build_model()
    print("batch_size={}".format(batch_size))
    fit_one_more(model, train_x, train_y, test_x, test_y, batch_size)

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

# %% [markdown]
# ## batch_size 적용 : [1,2,5,10,20,50,100,200,500]

# %%
fit_with_batch_sizes(train_x, train_y, test_x, test_y, batch_sizes=[1,2,5,10,20,50,100,200,500])
# Out:
# batch_size=1
# elapsed : 100.10004448890686
# batch_size=2
# elapsed : 51.167924642562866
# batch_size=5
# elapsed : 22.03675365447998
# batch_size=10
# elapsed : 11.979244947433472
# batch_size=20
# elapsed : 6.968225479125977
# batch_size=50
# elapsed : 5.585930347442627
# batch_size=100
# elapsed : 3.532036066055298
# batch_size=200
# elapsed : 3.595144510269165
# batch_size=500
# elapsed : 3.715965986251831

# %% [markdown]
# 맨 앞의 결과가 batch_size 1인 경우이다. 100개의 데이터를 매번 1개 씩 보냈고, 매번 업데이트 했다.
#
# batch_size를 키우면, 시간은 줄어들지만 학습이 빠르게 진행되지 않는다.

# %% [markdown]
# # 학습 진행된 내역 보기

# %% [markdown]
# ## model.fit()의 반환값 history
#
# 반환된 history의 loss로 진행 상황을 확인.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_24"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_81 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_82 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_83 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 7.2868006229400635

# %%
plt.plot(history.history['loss'])

# %% [markdown]
# ## model.fit() verbose
#
# - 0 : 진행하면서 아무런 출력 없이
# - 1 : 진행하면서 출력과 같이

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

print(train_x.shape)

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_25"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_84 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_85 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_86 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# (60000,)
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 101us/sample - loss: 0.2582 - mean_absolute_error: 0.4191
# Epoch 2/5
# 60000/60000 [==============================] - 6s 103us/sample - loss: 0.1067 - mean_absolute_error: 0.2194
# Epoch 3/5
# 60000/60000 [==============================] - 6s 100us/sample - loss: 0.0510 - mean_absolute_error: 0.1327
# Epoch 4/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.0170 - mean_absolute_error: 0.0835
# Epoch 5/5
# 60000/60000 [==============================] - 6s 99us/sample - loss: 0.0141 - mean_absolute_error: 0.0737
# elapsed : 30.706680059432983

# %% [markdown]
# # 학습 시에 validation

# %% [markdown]
# ## model.fit()의 validation_data

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=1, batch_size=20, validation_data=(test_x, test_y))
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_26"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_87 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_88 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_89 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60 samples, validate on 40 samples
# Epoch 1/1000
# 60/60 [==============================] - 0s 6ms/sample - loss: 0.6707 - mean_absolute_error: 0.7045 - val_loss: 0.3999 - val_mean_absolute_error: 0.5510
# Epoch 2/1000
# 60/60 [==============================] - 0s 232us/sample - loss: 0.5405 - mean_absolute_error: 0.6609 - val_loss: 0.3576 - val_mean_absolute_error: 0.5217
# Epoch 3/1000
# 60/60 [==============================] - 0s 295us/sample - loss: 0.5219 - mean_absolute_error: 0.6433 - val_loss: 0.3476 - val_mean_absolute_error: 0.5139
# Epoch 4/1000
# 60/60 [==============================] - 0s 242us/sample - loss: 0.5201 - mean_absolute_error: 0.6417 - val_loss: 0.3437 - val_mean_absolute_error: 0.5099
# Epoch 5/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.5163 - mean_absolute_error: 0.6384 - val_loss: 0.3426 - val_mean_absolute_error: 0.5089
# Epoch 6/1000
# 60/60 [==============================] - 0s 250us/sample - loss: 0.5207 - mean_absolute_error: 0.6429 - val_loss: 0.3392 - val_mean_absolute_error: 0.5046
# Epoch 7/1000
# 60/60 [==============================] - 0s 247us/sample - loss: 0.5178 - mean_absolute_error: 0.6427 - val_loss: 0.3367 - val_mean_absolute_error: 0.5009
# Epoch 8/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.5114 - mean_absolute_error: 0.6339 - val_loss: 0.3362 - val_mean_absolute_error: 0.5012
# Epoch 9/1000
# 60/60 [==============================] - 0s 249us/sample - loss: 0.5121 - mean_absolute_error: 0.6367 - val_loss: 0.3346 - val_mean_absolute_error: 0.4994
# Epoch 10/1000
# 60/60 [==============================] - 0s 275us/sample - loss: 0.5083 - mean_absolute_error: 0.6341 - val_loss: 0.3336 - val_mean_absolute_error: 0.4985
# Epoch 11/1000
# 60/60 [==============================] - 0s 272us/sample - loss: 0.5109 - mean_absolute_error: 0.6363 - val_loss: 0.3318 - val_mean_absolute_error: 0.4958
# Epoch 12/1000
# 60/60 [==============================] - 0s 286us/sample - loss: 0.5065 - mean_absolute_error: 0.6313 - val_loss: 0.3314 - val_mean_absolute_error: 0.4964
# Epoch 13/1000
# 60/60 [==============================] - 0s 225us/sample - loss: 0.5054 - mean_absolute_error: 0.6317 - val_loss: 0.3302 - val_mean_absolute_error: 0.4952
# Epoch 14/1000
# 60/60 [==============================] - 0s 241us/sample - loss: 0.5072 - mean_absolute_error: 0.6326 - val_loss: 0.3289 - val_mean_absolute_error: 0.4940
# Epoch 15/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.5016 - mean_absolute_error: 0.6293 - val_loss: 0.3282 - val_mean_absolute_error: 0.4939
# Epoch 16/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.5026 - mean_absolute_error: 0.6293 - val_loss: 0.3287 - val_mean_absolute_error: 0.4951
# Epoch 17/1000
# 60/60 [==============================] - 0s 242us/sample - loss: 0.5138 - mean_absolute_error: 0.6403 - val_loss: 0.3264 - val_mean_absolute_error: 0.4927
# Epoch 18/1000
# 60/60 [==============================] - 0s 237us/sample - loss: 0.4990 - mean_absolute_error: 0.6295 - val_loss: 0.3251 - val_mean_absolute_error: 0.4914
# Epoch 19/1000
# 60/60 [==============================] - 0s 271us/sample - loss: 0.4995 - mean_absolute_error: 0.6311 - val_loss: 0.3243 - val_mean_absolute_error: 0.4909
# Epoch 20/1000
# 60/60 [==============================] - 0s 233us/sample - loss: 0.4997 - mean_absolute_error: 0.6279 - val_loss: 0.3248 - val_mean_absolute_error: 0.4919
# Epoch 21/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.5065 - mean_absolute_error: 0.6348 - val_loss: 0.3233 - val_mean_absolute_error: 0.4906
# Epoch 22/1000
# 60/60 [==============================] - 0s 343us/sample - loss: 0.4952 - mean_absolute_error: 0.6283 - val_loss: 0.3202 - val_mean_absolute_error: 0.4865
# Epoch 23/1000
# 60/60 [==============================] - 0s 265us/sample - loss: 0.4977 - mean_absolute_error: 0.6263 - val_loss: 0.3189 - val_mean_absolute_error: 0.4852
# Epoch 24/1000
# 60/60 [==============================] - 0s 266us/sample - loss: 0.4931 - mean_absolute_error: 0.6237 - val_loss: 0.3195 - val_mean_absolute_error: 0.4869
# Epoch 25/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.4898 - mean_absolute_error: 0.6233 - val_loss: 0.3186 - val_mean_absolute_error: 0.4862
# Epoch 26/1000
# 60/60 [==============================] - 0s 291us/sample - loss: 0.4899 - mean_absolute_error: 0.6221 - val_loss: 0.3184 - val_mean_absolute_error: 0.4863
# Epoch 27/1000
# 60/60 [==============================] - 0s 340us/sample - loss: 0.4946 - mean_absolute_error: 0.6280 - val_loss: 0.3151 - val_mean_absolute_error: 0.4815
# Epoch 28/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4909 - mean_absolute_error: 0.6220 - val_loss: 0.3155 - val_mean_absolute_error: 0.4832
# Epoch 29/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.4883 - mean_absolute_error: 0.6224 - val_loss: 0.3153 - val_mean_absolute_error: 0.4833
# Epoch 30/1000
# 60/60 [==============================] - 0s 293us/sample - loss: 0.5153 - mean_absolute_error: 0.6377 - val_loss: 0.3148 - val_mean_absolute_error: 0.4830
# Epoch 31/1000
# 60/60 [==============================] - 0s 241us/sample - loss: 0.4947 - mean_absolute_error: 0.6254 - val_loss: 0.3164 - val_mean_absolute_error: 0.4848
# Epoch 32/1000
# 60/60 [==============================] - 0s 253us/sample - loss: 0.4944 - mean_absolute_error: 0.6245 - val_loss: 0.3160 - val_mean_absolute_error: 0.4844
# Epoch 33/1000
# 60/60 [==============================] - 0s 227us/sample - loss: 0.4831 - mean_absolute_error: 0.6215 - val_loss: 0.3118 - val_mean_absolute_error: 0.4805
# Epoch 34/1000
# 60/60 [==============================] - 0s 262us/sample - loss: 0.4907 - mean_absolute_error: 0.6269 - val_loss: 0.3087 - val_mean_absolute_error: 0.4759
# Epoch 35/1000
# 60/60 [==============================] - 0s 349us/sample - loss: 0.4852 - mean_absolute_error: 0.6186 - val_loss: 0.3080 - val_mean_absolute_error: 0.4756
# Epoch 36/1000
# 60/60 [==============================] - 0s 502us/sample - loss: 0.4800 - mean_absolute_error: 0.6154 - val_loss: 0.3084 - val_mean_absolute_error: 0.4775
# Epoch 37/1000
# 60/60 [==============================] - 0s 277us/sample - loss: 0.4828 - mean_absolute_error: 0.6207 - val_loss: 0.3070 - val_mean_absolute_error: 0.4759
# Epoch 38/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.4788 - mean_absolute_error: 0.6130 - val_loss: 0.3076 - val_mean_absolute_error: 0.4775
# Epoch 39/1000
# 60/60 [==============================] - 0s 290us/sample - loss: 0.4791 - mean_absolute_error: 0.6180 - val_loss: 0.3061 - val_mean_absolute_error: 0.4758
# Epoch 40/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4795 - mean_absolute_error: 0.6170 - val_loss: 0.3047 - val_mean_absolute_error: 0.4740
# Epoch 41/1000
# 60/60 [==============================] - 0s 253us/sample - loss: 0.4785 - mean_absolute_error: 0.6152 - val_loss: 0.3038 - val_mean_absolute_error: 0.4730
# Epoch 42/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4762 - mean_absolute_error: 0.6123 - val_loss: 0.3040 - val_mean_absolute_error: 0.4743
# Epoch 43/1000
# 60/60 [==============================] - 0s 238us/sample - loss: 0.4775 - mean_absolute_error: 0.6137 - val_loss: 0.3050 - val_mean_absolute_error: 0.4761
# Epoch 44/1000
# 60/60 [==============================] - 0s 295us/sample - loss: 0.4752 - mean_absolute_error: 0.6128 - val_loss: 0.3048 - val_mean_absolute_error: 0.4761
# Epoch 45/1000
# 60/60 [==============================] - 0s 248us/sample - loss: 0.4720 - mean_absolute_error: 0.6135 - val_loss: 0.3024 - val_mean_absolute_error: 0.4735
# Epoch 46/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.4763 - mean_absolute_error: 0.6126 - val_loss: 0.3016 - val_mean_absolute_error: 0.4728
# Epoch 47/1000
# 60/60 [==============================] - 0s 287us/sample - loss: 0.4703 - mean_absolute_error: 0.6094 - val_loss: 0.3011 - val_mean_absolute_error: 0.4725
# Epoch 48/1000
# 60/60 [==============================] - 0s 269us/sample - loss: 0.4761 - mean_absolute_error: 0.6174 - val_loss: 0.2992 - val_mean_absolute_error: 0.4693
# Epoch 49/1000
# 60/60 [==============================] - 0s 271us/sample - loss: 0.4786 - mean_absolute_error: 0.6149 - val_loss: 0.2985 - val_mean_absolute_error: 0.4682
# Epoch 50/1000
# 60/60 [==============================] - 0s 239us/sample - loss: 0.4696 - mean_absolute_error: 0.6087 - val_loss: 0.2979 - val_mean_absolute_error: 0.4677
# Epoch 51/1000
# 60/60 [==============================] - 0s 242us/sample - loss: 0.4706 - mean_absolute_error: 0.6086 - val_loss: 0.2972 - val_mean_absolute_error: 0.4670
# Epoch 52/1000
# 60/60 [==============================] - 0s 333us/sample - loss: 0.4657 - mean_absolute_error: 0.6055 - val_loss: 0.2974 - val_mean_absolute_error: 0.4690
# Epoch 53/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4665 - mean_absolute_error: 0.6064 - val_loss: 0.2980 - val_mean_absolute_error: 0.4703
# Epoch 54/1000
# 60/60 [==============================] - 0s 244us/sample - loss: 0.4653 - mean_absolute_error: 0.6068 - val_loss: 0.2977 - val_mean_absolute_error: 0.4703
# Epoch 55/1000
# 60/60 [==============================] - 0s 329us/sample - loss: 0.4704 - mean_absolute_error: 0.6144 - val_loss: 0.2954 - val_mean_absolute_error: 0.4669
# Epoch 56/1000
# 60/60 [==============================] - 0s 309us/sample - loss: 0.4717 - mean_absolute_error: 0.6128 - val_loss: 0.2949 - val_mean_absolute_error: 0.4664
# Epoch 57/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4707 - mean_absolute_error: 0.6156 - val_loss: 0.2939 - val_mean_absolute_error: 0.4637
# Epoch 58/1000
# 60/60 [==============================] - 0s 271us/sample - loss: 0.4645 - mean_absolute_error: 0.6052 - val_loss: 0.2936 - val_mean_absolute_error: 0.4649
# Epoch 59/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.4651 - mean_absolute_error: 0.6046 - val_loss: 0.2948 - val_mean_absolute_error: 0.4678
# Epoch 60/1000
# 60/60 [==============================] - 0s 261us/sample - loss: 0.4664 - mean_absolute_error: 0.6098 - val_loss: 0.2925 - val_mean_absolute_error: 0.4636
# Epoch 61/1000
# 60/60 [==============================] - 0s 345us/sample - loss: 0.4628 - mean_absolute_error: 0.6054 - val_loss: 0.2919 - val_mean_absolute_error: 0.4625
# Epoch 62/1000
# 60/60 [==============================] - 0s 304us/sample - loss: 0.4618 - mean_absolute_error: 0.6055 - val_loss: 0.2917 - val_mean_absolute_error: 0.4636
# Epoch 63/1000
# 60/60 [==============================] - 0s 348us/sample - loss: 0.4580 - mean_absolute_error: 0.6035 - val_loss: 0.2914 - val_mean_absolute_error: 0.4637
# Epoch 64/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4604 - mean_absolute_error: 0.6059 - val_loss: 0.2905 - val_mean_absolute_error: 0.4618
# Epoch 65/1000
# 60/60 [==============================] - 0s 295us/sample - loss: 0.4770 - mean_absolute_error: 0.6114 - val_loss: 0.2937 - val_mean_absolute_error: 0.4673
# Epoch 66/1000
# 60/60 [==============================] - 0s 233us/sample - loss: 0.4574 - mean_absolute_error: 0.6055 - val_loss: 0.2918 - val_mean_absolute_error: 0.4654
# Epoch 67/1000
# 60/60 [==============================] - 0s 280us/sample - loss: 0.4568 - mean_absolute_error: 0.6034 - val_loss: 0.2912 - val_mean_absolute_error: 0.4649
# Epoch 68/1000
# 60/60 [==============================] - 0s 237us/sample - loss: 0.4553 - mean_absolute_error: 0.6029 - val_loss: 0.2897 - val_mean_absolute_error: 0.4631
# Epoch 69/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.4548 - mean_absolute_error: 0.6018 - val_loss: 0.2897 - val_mean_absolute_error: 0.4633
# Epoch 70/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4529 - mean_absolute_error: 0.6005 - val_loss: 0.2888 - val_mean_absolute_error: 0.4622
# Epoch 71/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.4592 - mean_absolute_error: 0.6033 - val_loss: 0.2881 - val_mean_absolute_error: 0.4614
# Epoch 72/1000
# 60/60 [==============================] - 0s 257us/sample - loss: 0.4558 - mean_absolute_error: 0.6039 - val_loss: 0.2868 - val_mean_absolute_error: 0.4586
# Epoch 73/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4542 - mean_absolute_error: 0.6009 - val_loss: 0.2863 - val_mean_absolute_error: 0.4576
# Epoch 74/1000
# 60/60 [==============================] - 0s 262us/sample - loss: 0.4507 - mean_absolute_error: 0.5976 - val_loss: 0.2863 - val_mean_absolute_error: 0.4591
# Epoch 75/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4508 - mean_absolute_error: 0.5995 - val_loss: 0.2859 - val_mean_absolute_error: 0.4589
# Epoch 76/1000
# 60/60 [==============================] - 0s 257us/sample - loss: 0.4535 - mean_absolute_error: 0.6026 - val_loss: 0.2850 - val_mean_absolute_error: 0.4566
# Epoch 77/1000
# 60/60 [==============================] - 0s 270us/sample - loss: 0.4507 - mean_absolute_error: 0.5986 - val_loss: 0.2846 - val_mean_absolute_error: 0.4565
# Epoch 78/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.4497 - mean_absolute_error: 0.5968 - val_loss: 0.2852 - val_mean_absolute_error: 0.4587
# Epoch 79/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.4518 - mean_absolute_error: 0.6020 - val_loss: 0.2838 - val_mean_absolute_error: 0.4557
# Epoch 80/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.4522 - mean_absolute_error: 0.5993 - val_loss: 0.2850 - val_mean_absolute_error: 0.4590
# Epoch 81/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4502 - mean_absolute_error: 0.6032 - val_loss: 0.2832 - val_mean_absolute_error: 0.4560
# Epoch 82/1000
# 60/60 [==============================] - 0s 362us/sample - loss: 0.4570 - mean_absolute_error: 0.6015 - val_loss: 0.2856 - val_mean_absolute_error: 0.4599
# Epoch 83/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.4472 - mean_absolute_error: 0.6002 - val_loss: 0.2831 - val_mean_absolute_error: 0.4568
# Epoch 84/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.4475 - mean_absolute_error: 0.5989 - val_loss: 0.2819 - val_mean_absolute_error: 0.4546
# Epoch 85/1000
# 60/60 [==============================] - 0s 385us/sample - loss: 0.4539 - mean_absolute_error: 0.6035 - val_loss: 0.2817 - val_mean_absolute_error: 0.4550
# Epoch 86/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.4446 - mean_absolute_error: 0.5947 - val_loss: 0.2817 - val_mean_absolute_error: 0.4555
# Epoch 87/1000
# 60/60 [==============================] - 0s 309us/sample - loss: 0.4426 - mean_absolute_error: 0.5944 - val_loss: 0.2815 - val_mean_absolute_error: 0.4557
# Epoch 88/1000
# 60/60 [==============================] - 0s 354us/sample - loss: 0.4448 - mean_absolute_error: 0.5958 - val_loss: 0.2805 - val_mean_absolute_error: 0.4537
# Epoch 89/1000
# 60/60 [==============================] - 0s 267us/sample - loss: 0.4420 - mean_absolute_error: 0.5938 - val_loss: 0.2802 - val_mean_absolute_error: 0.4538
# Epoch 90/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4475 - mean_absolute_error: 0.5986 - val_loss: 0.2797 - val_mean_absolute_error: 0.4532
# Epoch 91/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.4530 - mean_absolute_error: 0.6013 - val_loss: 0.2794 - val_mean_absolute_error: 0.4515
# Epoch 92/1000
# 60/60 [==============================] - 0s 406us/sample - loss: 0.4440 - mean_absolute_error: 0.5935 - val_loss: 0.2790 - val_mean_absolute_error: 0.4523
# Epoch 93/1000
# 60/60 [==============================] - 0s 287us/sample - loss: 0.4405 - mean_absolute_error: 0.5925 - val_loss: 0.2789 - val_mean_absolute_error: 0.4531
# Epoch 94/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.4462 - mean_absolute_error: 0.5950 - val_loss: 0.2784 - val_mean_absolute_error: 0.4522
# Epoch 95/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4500 - mean_absolute_error: 0.5976 - val_loss: 0.2798 - val_mean_absolute_error: 0.4553
# Epoch 96/1000
# 60/60 [==============================] - 0s 377us/sample - loss: 0.4579 - mean_absolute_error: 0.6053 - val_loss: 0.2807 - val_mean_absolute_error: 0.4562
# Epoch 97/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4421 - mean_absolute_error: 0.5962 - val_loss: 0.2775 - val_mean_absolute_error: 0.4521
# Epoch 98/1000
# 60/60 [==============================] - 0s 281us/sample - loss: 0.4370 - mean_absolute_error: 0.5905 - val_loss: 0.2774 - val_mean_absolute_error: 0.4524
# Epoch 99/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4411 - mean_absolute_error: 0.5945 - val_loss: 0.2767 - val_mean_absolute_error: 0.4504
# Epoch 100/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.4374 - mean_absolute_error: 0.5897 - val_loss: 0.2767 - val_mean_absolute_error: 0.4518
# Epoch 101/1000
# 60/60 [==============================] - 0s 390us/sample - loss: 0.4354 - mean_absolute_error: 0.5898 - val_loss: 0.2763 - val_mean_absolute_error: 0.4513
# Epoch 102/1000
# 60/60 [==============================] - 0s 341us/sample - loss: 0.4345 - mean_absolute_error: 0.5895 - val_loss: 0.2762 - val_mean_absolute_error: 0.4516
# Epoch 103/1000
# 60/60 [==============================] - 0s 278us/sample - loss: 0.4391 - mean_absolute_error: 0.5930 - val_loss: 0.2755 - val_mean_absolute_error: 0.4492
# Epoch 104/1000
# 60/60 [==============================] - 0s 250us/sample - loss: 0.4377 - mean_absolute_error: 0.5890 - val_loss: 0.2754 - val_mean_absolute_error: 0.4505
# Epoch 105/1000
# 60/60 [==============================] - 0s 400us/sample - loss: 0.4411 - mean_absolute_error: 0.5947 - val_loss: 0.2755 - val_mean_absolute_error: 0.4513
# Epoch 106/1000
# 60/60 [==============================] - 0s 246us/sample - loss: 0.4420 - mean_absolute_error: 0.5956 - val_loss: 0.2749 - val_mean_absolute_error: 0.4477
# Epoch 107/1000
# 60/60 [==============================] - 0s 326us/sample - loss: 0.4334 - mean_absolute_error: 0.5871 - val_loss: 0.2746 - val_mean_absolute_error: 0.4501
# Epoch 108/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4359 - mean_absolute_error: 0.5902 - val_loss: 0.2741 - val_mean_absolute_error: 0.4487
# Epoch 109/1000
# 60/60 [==============================] - 0s 338us/sample - loss: 0.4361 - mean_absolute_error: 0.5903 - val_loss: 0.2739 - val_mean_absolute_error: 0.4488
# Epoch 110/1000
# 60/60 [==============================] - 0s 282us/sample - loss: 0.4356 - mean_absolute_error: 0.5887 - val_loss: 0.2752 - val_mean_absolute_error: 0.4519
# Epoch 111/1000
# 60/60 [==============================] - 0s 333us/sample - loss: 0.4311 - mean_absolute_error: 0.5876 - val_loss: 0.2743 - val_mean_absolute_error: 0.4508
# Epoch 112/1000
# 60/60 [==============================] - 0s 252us/sample - loss: 0.4302 - mean_absolute_error: 0.5882 - val_loss: 0.2732 - val_mean_absolute_error: 0.4490
# Epoch 113/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.4304 - mean_absolute_error: 0.5863 - val_loss: 0.2736 - val_mean_absolute_error: 0.4501
# Epoch 114/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4313 - mean_absolute_error: 0.5883 - val_loss: 0.2728 - val_mean_absolute_error: 0.4490
# Epoch 115/1000
# 60/60 [==============================] - 0s 322us/sample - loss: 0.4305 - mean_absolute_error: 0.5895 - val_loss: 0.2722 - val_mean_absolute_error: 0.4471
# Epoch 116/1000
# 60/60 [==============================] - 0s 315us/sample - loss: 0.4356 - mean_absolute_error: 0.5868 - val_loss: 0.2734 - val_mean_absolute_error: 0.4503
# Epoch 117/1000
# 60/60 [==============================] - 0s 257us/sample - loss: 0.4329 - mean_absolute_error: 0.5890 - val_loss: 0.2724 - val_mean_absolute_error: 0.4490
# Epoch 118/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.4296 - mean_absolute_error: 0.5849 - val_loss: 0.2726 - val_mean_absolute_error: 0.4496
# Epoch 119/1000
# 60/60 [==============================] - 0s 398us/sample - loss: 0.4365 - mean_absolute_error: 0.5933 - val_loss: 0.2712 - val_mean_absolute_error: 0.4462
# Epoch 120/1000
# 60/60 [==============================] - 0s 256us/sample - loss: 0.4348 - mean_absolute_error: 0.5901 - val_loss: 0.2710 - val_mean_absolute_error: 0.4452
# Epoch 121/1000
# 60/60 [==============================] - 0s 272us/sample - loss: 0.4305 - mean_absolute_error: 0.5861 - val_loss: 0.2714 - val_mean_absolute_error: 0.4482
# Epoch 122/1000
# 60/60 [==============================] - 0s 243us/sample - loss: 0.4363 - mean_absolute_error: 0.5910 - val_loss: 0.2712 - val_mean_absolute_error: 0.4482
# Epoch 123/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.4361 - mean_absolute_error: 0.5924 - val_loss: 0.2711 - val_mean_absolute_error: 0.4482
# Epoch 124/1000
# 60/60 [==============================] - 0s 269us/sample - loss: 0.4421 - mean_absolute_error: 0.5918 - val_loss: 0.2711 - val_mean_absolute_error: 0.4484
# Epoch 125/1000
# 60/60 [==============================] - 0s 254us/sample - loss: 0.4287 - mean_absolute_error: 0.5883 - val_loss: 0.2705 - val_mean_absolute_error: 0.4476
# Epoch 126/1000
# 60/60 [==============================] - 0s 273us/sample - loss: 0.4280 - mean_absolute_error: 0.5859 - val_loss: 0.2709 - val_mean_absolute_error: 0.4483
# Epoch 127/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.4255 - mean_absolute_error: 0.5861 - val_loss: 0.2692 - val_mean_absolute_error: 0.4453
# Epoch 128/1000
# 60/60 [==============================] - 0s 377us/sample - loss: 0.4292 - mean_absolute_error: 0.5861 - val_loss: 0.2690 - val_mean_absolute_error: 0.4453
# Epoch 129/1000
# 60/60 [==============================] - 0s 264us/sample - loss: 0.4247 - mean_absolute_error: 0.5843 - val_loss: 0.2688 - val_mean_absolute_error: 0.4455
# Epoch 130/1000
# 60/60 [==============================] - 0s 267us/sample - loss: 0.4244 - mean_absolute_error: 0.5823 - val_loss: 0.2688 - val_mean_absolute_error: 0.4460
# Epoch 131/1000
# 60/60 [==============================] - 0s 278us/sample - loss: 0.4224 - mean_absolute_error: 0.5827 - val_loss: 0.2682 - val_mean_absolute_error: 0.4446
# Epoch 132/1000
# 60/60 [==============================] - 0s 273us/sample - loss: 0.4265 - mean_absolute_error: 0.5825 - val_loss: 0.2687 - val_mean_absolute_error: 0.4463
# Epoch 133/1000
# 60/60 [==============================] - 0s 337us/sample - loss: 0.4214 - mean_absolute_error: 0.5804 - val_loss: 0.2687 - val_mean_absolute_error: 0.4465
# Epoch 134/1000
# 60/60 [==============================] - 0s 245us/sample - loss: 0.4203 - mean_absolute_error: 0.5819 - val_loss: 0.2676 - val_mean_absolute_error: 0.4448
# Epoch 135/1000
# 60/60 [==============================] - 0s 335us/sample - loss: 0.4195 - mean_absolute_error: 0.5791 - val_loss: 0.2678 - val_mean_absolute_error: 0.4457
# Epoch 136/1000
# 60/60 [==============================] - 0s 257us/sample - loss: 0.4234 - mean_absolute_error: 0.5817 - val_loss: 0.2671 - val_mean_absolute_error: 0.4446
# Epoch 137/1000
# 60/60 [==============================] - 0s 249us/sample - loss: 0.4226 - mean_absolute_error: 0.5830 - val_loss: 0.2667 - val_mean_absolute_error: 0.4436
# Epoch 138/1000
# 60/60 [==============================] - 0s 244us/sample - loss: 0.4211 - mean_absolute_error: 0.5779 - val_loss: 0.2678 - val_mean_absolute_error: 0.4461
# Epoch 139/1000
# 60/60 [==============================] - 0s 342us/sample - loss: 0.4203 - mean_absolute_error: 0.5809 - val_loss: 0.2673 - val_mean_absolute_error: 0.4457
# Epoch 140/1000
# 60/60 [==============================] - 0s 400us/sample - loss: 0.4184 - mean_absolute_error: 0.5800 - val_loss: 0.2662 - val_mean_absolute_error: 0.4444
# Epoch 141/1000
# 60/60 [==============================] - 0s 328us/sample - loss: 0.4270 - mean_absolute_error: 0.5869 - val_loss: 0.2658 - val_mean_absolute_error: 0.4433
# Epoch 142/1000
# 60/60 [==============================] - 0s 268us/sample - loss: 0.4243 - mean_absolute_error: 0.5842 - val_loss: 0.2664 - val_mean_absolute_error: 0.4414
# Epoch 143/1000
# 60/60 [==============================] - 0s 258us/sample - loss: 0.4168 - mean_absolute_error: 0.5783 - val_loss: 0.2653 - val_mean_absolute_error: 0.4424
# Epoch 144/1000
# 60/60 [==============================] - 0s 265us/sample - loss: 0.4146 - mean_absolute_error: 0.5764 - val_loss: 0.2651 - val_mean_absolute_error: 0.4433
# Epoch 145/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.4307 - mean_absolute_error: 0.5844 - val_loss: 0.2675 - val_mean_absolute_error: 0.4464
# Epoch 146/1000
# 60/60 [==============================] - 0s 428us/sample - loss: 0.4303 - mean_absolute_error: 0.5791 - val_loss: 0.2648 - val_mean_absolute_error: 0.4434
# Epoch 147/1000
# 60/60 [==============================] - 0s 280us/sample - loss: 0.4194 - mean_absolute_error: 0.5833 - val_loss: 0.2644 - val_mean_absolute_error: 0.4423
# Epoch 148/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.4148 - mean_absolute_error: 0.5786 - val_loss: 0.2641 - val_mean_absolute_error: 0.4417
# Epoch 149/1000
# 60/60 [==============================] - 0s 352us/sample - loss: 0.4191 - mean_absolute_error: 0.5785 - val_loss: 0.2662 - val_mean_absolute_error: 0.4455
# Epoch 150/1000
# 60/60 [==============================] - 0s 369us/sample - loss: 0.4124 - mean_absolute_error: 0.5769 - val_loss: 0.2641 - val_mean_absolute_error: 0.4432
# Epoch 151/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4128 - mean_absolute_error: 0.5767 - val_loss: 0.2643 - val_mean_absolute_error: 0.4437
# Epoch 152/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.4130 - mean_absolute_error: 0.5770 - val_loss: 0.2636 - val_mean_absolute_error: 0.4429
# Epoch 153/1000
# 60/60 [==============================] - 0s 352us/sample - loss: 0.4175 - mean_absolute_error: 0.5790 - val_loss: 0.2634 - val_mean_absolute_error: 0.4402
# Epoch 154/1000
# 60/60 [==============================] - 0s 398us/sample - loss: 0.4150 - mean_absolute_error: 0.5779 - val_loss: 0.2627 - val_mean_absolute_error: 0.4407
# Epoch 155/1000
# 60/60 [==============================] - 0s 352us/sample - loss: 0.4114 - mean_absolute_error: 0.5738 - val_loss: 0.2624 - val_mean_absolute_error: 0.4411
# Epoch 156/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.4113 - mean_absolute_error: 0.5740 - val_loss: 0.2622 - val_mean_absolute_error: 0.4412
# Epoch 157/1000
# 60/60 [==============================] - 0s 357us/sample - loss: 0.4112 - mean_absolute_error: 0.5735 - val_loss: 0.2632 - val_mean_absolute_error: 0.4431
# Epoch 158/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4140 - mean_absolute_error: 0.5776 - val_loss: 0.2640 - val_mean_absolute_error: 0.4442
# Epoch 159/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4135 - mean_absolute_error: 0.5768 - val_loss: 0.2615 - val_mean_absolute_error: 0.4403
# Epoch 160/1000
# 60/60 [==============================] - 0s 245us/sample - loss: 0.4144 - mean_absolute_error: 0.5746 - val_loss: 0.2633 - val_mean_absolute_error: 0.4435
# Epoch 161/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4094 - mean_absolute_error: 0.5755 - val_loss: 0.2616 - val_mean_absolute_error: 0.4416
# Epoch 162/1000
# 60/60 [==============================] - 0s 427us/sample - loss: 0.4155 - mean_absolute_error: 0.5777 - val_loss: 0.2624 - val_mean_absolute_error: 0.4389
# Epoch 163/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.4065 - mean_absolute_error: 0.5690 - val_loss: 0.2606 - val_mean_absolute_error: 0.4399
# Epoch 164/1000
# 60/60 [==============================] - 0s 287us/sample - loss: 0.4069 - mean_absolute_error: 0.5730 - val_loss: 0.2606 - val_mean_absolute_error: 0.4388
# Epoch 165/1000
# 60/60 [==============================] - 0s 289us/sample - loss: 0.4100 - mean_absolute_error: 0.5732 - val_loss: 0.2606 - val_mean_absolute_error: 0.4408
# Epoch 166/1000
# 60/60 [==============================] - 0s 260us/sample - loss: 0.4045 - mean_absolute_error: 0.5722 - val_loss: 0.2598 - val_mean_absolute_error: 0.4391
# Epoch 167/1000
# 60/60 [==============================] - 0s 347us/sample - loss: 0.4204 - mean_absolute_error: 0.5810 - val_loss: 0.2630 - val_mean_absolute_error: 0.4380
# Epoch 168/1000
# 60/60 [==============================] - 0s 261us/sample - loss: 0.4174 - mean_absolute_error: 0.5727 - val_loss: 0.2594 - val_mean_absolute_error: 0.4385
# Epoch 169/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.4253 - mean_absolute_error: 0.5875 - val_loss: 0.2636 - val_mean_absolute_error: 0.4377
# Epoch 170/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4176 - mean_absolute_error: 0.5759 - val_loss: 0.2589 - val_mean_absolute_error: 0.4382
# Epoch 171/1000
# 60/60 [==============================] - 0s 438us/sample - loss: 0.4052 - mean_absolute_error: 0.5695 - val_loss: 0.2598 - val_mean_absolute_error: 0.4406
# Epoch 172/1000
# 60/60 [==============================] - 0s 252us/sample - loss: 0.4014 - mean_absolute_error: 0.5696 - val_loss: 0.2588 - val_mean_absolute_error: 0.4393
# Epoch 173/1000
# 60/60 [==============================] - 0s 261us/sample - loss: 0.4025 - mean_absolute_error: 0.5677 - val_loss: 0.2593 - val_mean_absolute_error: 0.4402
# Epoch 174/1000
# 60/60 [==============================] - 0s 317us/sample - loss: 0.4006 - mean_absolute_error: 0.5685 - val_loss: 0.2583 - val_mean_absolute_error: 0.4390
# Epoch 175/1000
# 60/60 [==============================] - 0s 316us/sample - loss: 0.4019 - mean_absolute_error: 0.5680 - val_loss: 0.2579 - val_mean_absolute_error: 0.4373
# Epoch 176/1000
# 60/60 [==============================] - 0s 292us/sample - loss: 0.4027 - mean_absolute_error: 0.5661 - val_loss: 0.2578 - val_mean_absolute_error: 0.4385
# Epoch 177/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.4039 - mean_absolute_error: 0.5696 - val_loss: 0.2574 - val_mean_absolute_error: 0.4381
# Epoch 178/1000
# 60/60 [==============================] - 0s 256us/sample - loss: 0.3980 - mean_absolute_error: 0.5667 - val_loss: 0.2572 - val_mean_absolute_error: 0.4378
# Epoch 179/1000
# 60/60 [==============================] - 0s 290us/sample - loss: 0.4002 - mean_absolute_error: 0.5678 - val_loss: 0.2574 - val_mean_absolute_error: 0.4366
# Epoch 180/1000
# 60/60 [==============================] - 0s 374us/sample - loss: 0.3970 - mean_absolute_error: 0.5634 - val_loss: 0.2566 - val_mean_absolute_error: 0.4371
# Epoch 181/1000
# 60/60 [==============================] - 0s 263us/sample - loss: 0.4048 - mean_absolute_error: 0.5732 - val_loss: 0.2573 - val_mean_absolute_error: 0.4388
# Epoch 182/1000
# 60/60 [==============================] - 0s 258us/sample - loss: 0.4097 - mean_absolute_error: 0.5717 - val_loss: 0.2560 - val_mean_absolute_error: 0.4364
# Epoch 183/1000
# 60/60 [==============================] - 0s 260us/sample - loss: 0.3950 - mean_absolute_error: 0.5643 - val_loss: 0.2558 - val_mean_absolute_error: 0.4365
# Epoch 184/1000
# 60/60 [==============================] - 0s 280us/sample - loss: 0.3964 - mean_absolute_error: 0.5648 - val_loss: 0.2564 - val_mean_absolute_error: 0.4377
# Epoch 185/1000
# 60/60 [==============================] - 0s 245us/sample - loss: 0.3959 - mean_absolute_error: 0.5658 - val_loss: 0.2553 - val_mean_absolute_error: 0.4359
# Epoch 186/1000
# 60/60 [==============================] - 0s 255us/sample - loss: 0.4043 - mean_absolute_error: 0.5700 - val_loss: 0.2552 - val_mean_absolute_error: 0.4355
# Epoch 187/1000
# 60/60 [==============================] - 0s 299us/sample - loss: 0.4687 - mean_absolute_error: 0.6068 - val_loss: 0.2559 - val_mean_absolute_error: 0.4377
# Epoch 188/1000
# 60/60 [==============================] - 0s 401us/sample - loss: 0.3985 - mean_absolute_error: 0.5678 - val_loss: 0.2558 - val_mean_absolute_error: 0.4352
# Epoch 189/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.3985 - mean_absolute_error: 0.5638 - val_loss: 0.2562 - val_mean_absolute_error: 0.4393
# Epoch 190/1000
# 60/60 [==============================] - 0s 382us/sample - loss: 0.3920 - mean_absolute_error: 0.5645 - val_loss: 0.2542 - val_mean_absolute_error: 0.4351
# Epoch 191/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.4116 - mean_absolute_error: 0.5706 - val_loss: 0.2543 - val_mean_absolute_error: 0.4349
# Epoch 192/1000
# 60/60 [==============================] - 0s 266us/sample - loss: 0.4015 - mean_absolute_error: 0.5683 - val_loss: 0.2537 - val_mean_absolute_error: 0.4349
# Epoch 193/1000
# 60/60 [==============================] - 0s 321us/sample - loss: 0.3932 - mean_absolute_error: 0.5639 - val_loss: 0.2537 - val_mean_absolute_error: 0.4348
# Epoch 194/1000
# 60/60 [==============================] - 0s 288us/sample - loss: 0.3922 - mean_absolute_error: 0.5628 - val_loss: 0.2546 - val_mean_absolute_error: 0.4377
# Epoch 195/1000
# 60/60 [==============================] - 0s 381us/sample - loss: 0.3947 - mean_absolute_error: 0.5651 - val_loss: 0.2550 - val_mean_absolute_error: 0.4344
# Epoch 196/1000
# 60/60 [==============================] - 0s 438us/sample - loss: 0.3899 - mean_absolute_error: 0.5569 - val_loss: 0.2533 - val_mean_absolute_error: 0.4351
# Epoch 197/1000
# 60/60 [==============================] - 0s 340us/sample - loss: 0.3907 - mean_absolute_error: 0.5621 - val_loss: 0.2528 - val_mean_absolute_error: 0.4339
# Epoch 198/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.4051 - mean_absolute_error: 0.5693 - val_loss: 0.2534 - val_mean_absolute_error: 0.4339
# Epoch 199/1000
# 60/60 [==============================] - 0s 400us/sample - loss: 0.3903 - mean_absolute_error: 0.5562 - val_loss: 0.2530 - val_mean_absolute_error: 0.4360
# Epoch 200/1000
# 60/60 [==============================] - 0s 301us/sample - loss: 0.4030 - mean_absolute_error: 0.5687 - val_loss: 0.2518 - val_mean_absolute_error: 0.4334
# Epoch 201/1000
# 60/60 [==============================] - 0s 305us/sample - loss: 0.3889 - mean_absolute_error: 0.5624 - val_loss: 0.2530 - val_mean_absolute_error: 0.4336
# Epoch 202/1000
# 60/60 [==============================] - 0s 279us/sample - loss: 0.3966 - mean_absolute_error: 0.5626 - val_loss: 0.2512 - val_mean_absolute_error: 0.4331
# Epoch 203/1000
# 60/60 [==============================] - 0s 414us/sample - loss: 0.3903 - mean_absolute_error: 0.5636 - val_loss: 0.2510 - val_mean_absolute_error: 0.4329
# Epoch 204/1000
# 60/60 [==============================] - 0s 285us/sample - loss: 0.3873 - mean_absolute_error: 0.5571 - val_loss: 0.2508 - val_mean_absolute_error: 0.4327
# Epoch 205/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.4030 - mean_absolute_error: 0.5662 - val_loss: 0.2505 - val_mean_absolute_error: 0.4326
# Epoch 206/1000
# 60/60 [==============================] - 0s 302us/sample - loss: 0.3835 - mean_absolute_error: 0.5567 - val_loss: 0.2507 - val_mean_absolute_error: 0.4327
# Epoch 207/1000
# 60/60 [==============================] - 0s 283us/sample - loss: 0.3899 - mean_absolute_error: 0.5608 - val_loss: 0.2514 - val_mean_absolute_error: 0.4327
# Epoch 208/1000
# 60/60 [==============================] - 0s 359us/sample - loss: 0.3941 - mean_absolute_error: 0.5616 - val_loss: 0.2507 - val_mean_absolute_error: 0.4342
# Epoch 209/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.3872 - mean_absolute_error: 0.5604 - val_loss: 0.2500 - val_mean_absolute_error: 0.4322
# Epoch 210/1000
# 60/60 [==============================] - 0s 392us/sample - loss: 0.3851 - mean_absolute_error: 0.5569 - val_loss: 0.2506 - val_mean_absolute_error: 0.4322
# Epoch 211/1000
# 60/60 [==============================] - 0s 305us/sample - loss: 0.3864 - mean_absolute_error: 0.5541 - val_loss: 0.2501 - val_mean_absolute_error: 0.4342
# Epoch 212/1000
# 60/60 [==============================] - 0s 392us/sample - loss: 0.3847 - mean_absolute_error: 0.5592 - val_loss: 0.2526 - val_mean_absolute_error: 0.4324
# Epoch 213/1000
# 60/60 [==============================] - 0s 273us/sample - loss: 0.3945 - mean_absolute_error: 0.5633 - val_loss: 0.2532 - val_mean_absolute_error: 0.4327
# Epoch 214/1000
# 60/60 [==============================] - 0s 251us/sample - loss: 0.4094 - mean_absolute_error: 0.5728 - val_loss: 0.2503 - val_mean_absolute_error: 0.4317
# Epoch 215/1000
# 60/60 [==============================] - 0s 356us/sample - loss: 0.3817 - mean_absolute_error: 0.5512 - val_loss: 0.2485 - val_mean_absolute_error: 0.4323
# Epoch 216/1000
# 60/60 [==============================] - 0s 337us/sample - loss: 0.3786 - mean_absolute_error: 0.5534 - val_loss: 0.2481 - val_mean_absolute_error: 0.4319
# Epoch 217/1000
# 60/60 [==============================] - 0s 298us/sample - loss: 0.3804 - mean_absolute_error: 0.5562 - val_loss: 0.2480 - val_mean_absolute_error: 0.4323
# Epoch 218/1000
# 60/60 [==============================] - 0s 250us/sample - loss: 0.3933 - mean_absolute_error: 0.5621 - val_loss: 0.2487 - val_mean_absolute_error: 0.4340
# Epoch 219/1000
# 60/60 [==============================] - 0s 294us/sample - loss: 0.3776 - mean_absolute_error: 0.5513 - val_loss: 0.2475 - val_mean_absolute_error: 0.4320
# Epoch 220/1000
# 60/60 [==============================] - 0s 282us/sample - loss: 0.3749 - mean_absolute_error: 0.5509 - val_loss: 0.2470 - val_mean_absolute_error: 0.4304
# Epoch 221/1000
# 60/60 [==============================] - 0s 428us/sample - loss: 0.3779 - mean_absolute_error: 0.5484 - val_loss: 0.2480 - val_mean_absolute_error: 0.4337
# Epoch 222/1000
# 60/60 [==============================] - 0s 332us/sample - loss: 0.3793 - mean_absolute_error: 0.5536 - val_loss: 0.2464 - val_mean_absolute_error: 0.4300
# Epoch 223/1000
# 60/60 [==============================] - 0s 479us/sample - loss: 0.4019 - mean_absolute_error: 0.5680 - val_loss: 0.2524 - val_mean_absolute_error: 0.4323
# Epoch 224/1000
# 60/60 [==============================] - 0s 306us/sample - loss: 0.3803 - mean_absolute_error: 0.5555 - val_loss: 0.2482 - val_mean_absolute_error: 0.4301
# Epoch 225/1000
# 60/60 [==============================] - 0s 379us/sample - loss: 0.3834 - mean_absolute_error: 0.5490 - val_loss: 0.2472 - val_mean_absolute_error: 0.4334
# Epoch 226/1000
# 60/60 [==============================] - 0s 304us/sample - loss: 0.3978 - mean_absolute_error: 0.5659 - val_loss: 0.2453 - val_mean_absolute_error: 0.4301
# Epoch 227/1000
# 60/60 [==============================] - 0s 308us/sample - loss: 0.3922 - mean_absolute_error: 0.5682 - val_loss: 0.2451 - val_mean_absolute_error: 0.4298
# Epoch 228/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.3704 - mean_absolute_error: 0.5456 - val_loss: 0.2449 - val_mean_absolute_error: 0.4300
# Epoch 229/1000
# 60/60 [==============================] - 0s 320us/sample - loss: 0.3804 - mean_absolute_error: 0.5502 - val_loss: 0.2500 - val_mean_absolute_error: 0.4379
# Epoch 230/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.3778 - mean_absolute_error: 0.5479 - val_loss: 0.2448 - val_mean_absolute_error: 0.4310
# Epoch 231/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.3840 - mean_absolute_error: 0.5559 - val_loss: 0.2479 - val_mean_absolute_error: 0.4300
# Epoch 232/1000
# 60/60 [==============================] - 0s 338us/sample - loss: 0.3713 - mean_absolute_error: 0.5437 - val_loss: 0.2438 - val_mean_absolute_error: 0.4292
# Epoch 233/1000
# 60/60 [==============================] - 0s 345us/sample - loss: 0.3762 - mean_absolute_error: 0.5482 - val_loss: 0.2445 - val_mean_absolute_error: 0.4315
# Epoch 234/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.3697 - mean_absolute_error: 0.5469 - val_loss: 0.2461 - val_mean_absolute_error: 0.4290
# Epoch 235/1000
# 60/60 [==============================] - 0s 354us/sample - loss: 0.3683 - mean_absolute_error: 0.5439 - val_loss: 0.2438 - val_mean_absolute_error: 0.4278
# Epoch 236/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.3662 - mean_absolute_error: 0.5415 - val_loss: 0.2429 - val_mean_absolute_error: 0.4291
# Epoch 237/1000
# 60/60 [==============================] - 0s 360us/sample - loss: 0.3862 - mean_absolute_error: 0.5575 - val_loss: 0.2477 - val_mean_absolute_error: 0.4298
# Epoch 238/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.3791 - mean_absolute_error: 0.5572 - val_loss: 0.2454 - val_mean_absolute_error: 0.4285
# Epoch 239/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.3858 - mean_absolute_error: 0.5485 - val_loss: 0.2437 - val_mean_absolute_error: 0.4274
# Epoch 240/1000
# 60/60 [==============================] - 0s 315us/sample - loss: 0.3681 - mean_absolute_error: 0.5420 - val_loss: 0.2432 - val_mean_absolute_error: 0.4312
# Epoch 241/1000
# 60/60 [==============================] - 0s 388us/sample - loss: 0.3791 - mean_absolute_error: 0.5462 - val_loss: 0.2505 - val_mean_absolute_error: 0.4399
# Epoch 242/1000
# 60/60 [==============================] - 0s 310us/sample - loss: 0.3660 - mean_absolute_error: 0.5462 - val_loss: 0.2413 - val_mean_absolute_error: 0.4278
# Epoch 243/1000
# 60/60 [==============================] - 0s 284us/sample - loss: 0.3709 - mean_absolute_error: 0.5476 - val_loss: 0.2422 - val_mean_absolute_error: 0.4304
# Epoch 244/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.3833 - mean_absolute_error: 0.5467 - val_loss: 0.2557 - val_mean_absolute_error: 0.4455
# Epoch 245/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.3829 - mean_absolute_error: 0.5498 - val_loss: 0.2428 - val_mean_absolute_error: 0.4315
# Epoch 246/1000
# 60/60 [==============================] - 0s 462us/sample - loss: 0.3738 - mean_absolute_error: 0.5449 - val_loss: 0.2411 - val_mean_absolute_error: 0.4262
# Epoch 247/1000
# 60/60 [==============================] - 0s 563us/sample - loss: 0.3622 - mean_absolute_error: 0.5406 - val_loss: 0.2430 - val_mean_absolute_error: 0.4270
# Epoch 248/1000
# 60/60 [==============================] - 0s 589us/sample - loss: 0.3601 - mean_absolute_error: 0.5346 - val_loss: 0.2409 - val_mean_absolute_error: 0.4298
# Epoch 249/1000
# 60/60 [==============================] - 0s 501us/sample - loss: 0.3592 - mean_absolute_error: 0.5385 - val_loss: 0.2396 - val_mean_absolute_error: 0.4268
# Epoch 250/1000
# 60/60 [==============================] - 0s 345us/sample - loss: 0.3600 - mean_absolute_error: 0.5379 - val_loss: 0.2407 - val_mean_absolute_error: 0.4299
# Epoch 251/1000
# 60/60 [==============================] - 0s 372us/sample - loss: 0.3585 - mean_absolute_error: 0.5383 - val_loss: 0.2416 - val_mean_absolute_error: 0.4261
# Epoch 252/1000
# 60/60 [==============================] - 0s 355us/sample - loss: 0.3939 - mean_absolute_error: 0.5545 - val_loss: 0.2548 - val_mean_absolute_error: 0.4312
# Epoch 253/1000
# 60/60 [==============================] - 0s 429us/sample - loss: 0.3749 - mean_absolute_error: 0.5394 - val_loss: 0.2453 - val_mean_absolute_error: 0.4279
# Epoch 254/1000
# 60/60 [==============================] - 0s 486us/sample - loss: 0.3607 - mean_absolute_error: 0.5371 - val_loss: 0.2407 - val_mean_absolute_error: 0.4255
# Epoch 255/1000
# 60/60 [==============================] - 0s 433us/sample - loss: 0.3583 - mean_absolute_error: 0.5334 - val_loss: 0.2382 - val_mean_absolute_error: 0.4270
# Epoch 256/1000
# 60/60 [==============================] - 0s 396us/sample - loss: 0.3655 - mean_absolute_error: 0.5391 - val_loss: 0.2379 - val_mean_absolute_error: 0.4265
# Epoch 257/1000
# 60/60 [==============================] - 0s 375us/sample - loss: 0.3602 - mean_absolute_error: 0.5400 - val_loss: 0.2379 - val_mean_absolute_error: 0.4243
# Epoch 258/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.3538 - mean_absolute_error: 0.5309 - val_loss: 0.2382 - val_mean_absolute_error: 0.4280
# Epoch 259/1000
# 60/60 [==============================] - 0s 361us/sample - loss: 0.3534 - mean_absolute_error: 0.5308 - val_loss: 0.2371 - val_mean_absolute_error: 0.4259
# Epoch 260/1000
# 60/60 [==============================] - 0s 332us/sample - loss: 0.3672 - mean_absolute_error: 0.5404 - val_loss: 0.2389 - val_mean_absolute_error: 0.4292
# Epoch 261/1000
# 60/60 [==============================] - 0s 311us/sample - loss: 0.3659 - mean_absolute_error: 0.5417 - val_loss: 0.2414 - val_mean_absolute_error: 0.4256
# Epoch 262/1000
# 60/60 [==============================] - 0s 451us/sample - loss: 0.3535 - mean_absolute_error: 0.5322 - val_loss: 0.2365 - val_mean_absolute_error: 0.4235
# Epoch 263/1000
# 60/60 [==============================] - 0s 308us/sample - loss: 0.3532 - mean_absolute_error: 0.5304 - val_loss: 0.2431 - val_mean_absolute_error: 0.4262
# Epoch 264/1000
# 60/60 [==============================] - 0s 450us/sample - loss: 0.3522 - mean_absolute_error: 0.5242 - val_loss: 0.2357 - val_mean_absolute_error: 0.4243
# Epoch 265/1000
# 60/60 [==============================] - 0s 312us/sample - loss: 0.3584 - mean_absolute_error: 0.5302 - val_loss: 0.2459 - val_mean_absolute_error: 0.4377
# Epoch 266/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.3511 - mean_absolute_error: 0.5280 - val_loss: 0.2354 - val_mean_absolute_error: 0.4227
# Epoch 267/1000
# 60/60 [==============================] - 0s 412us/sample - loss: 0.3720 - mean_absolute_error: 0.5373 - val_loss: 0.2594 - val_mean_absolute_error: 0.4491
# Epoch 268/1000
# 60/60 [==============================] - 0s 379us/sample - loss: 0.3655 - mean_absolute_error: 0.5397 - val_loss: 0.2362 - val_mean_absolute_error: 0.4271
# Epoch 269/1000
# 60/60 [==============================] - 0s 389us/sample - loss: 0.3684 - mean_absolute_error: 0.5327 - val_loss: 0.2444 - val_mean_absolute_error: 0.4364
# Epoch 270/1000
# 60/60 [==============================] - 0s 334us/sample - loss: 0.3775 - mean_absolute_error: 0.5505 - val_loss: 0.2475 - val_mean_absolute_error: 0.4270
# Epoch 271/1000
# 60/60 [==============================] - 0s 307us/sample - loss: 0.3600 - mean_absolute_error: 0.5329 - val_loss: 0.2342 - val_mean_absolute_error: 0.4220
# Epoch 272/1000
# 60/60 [==============================] - 0s 385us/sample - loss: 0.3468 - mean_absolute_error: 0.5228 - val_loss: 0.2366 - val_mean_absolute_error: 0.4280
# Epoch 273/1000
# 60/60 [==============================] - 0s 400us/sample - loss: 0.3445 - mean_absolute_error: 0.5237 - val_loss: 0.2408 - val_mean_absolute_error: 0.4243
# Epoch 274/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.3596 - mean_absolute_error: 0.5298 - val_loss: 0.2437 - val_mean_absolute_error: 0.4253
# Epoch 275/1000
# 60/60 [==============================] - 0s 310us/sample - loss: 0.3626 - mean_absolute_error: 0.5273 - val_loss: 0.2383 - val_mean_absolute_error: 0.4231
# Epoch 276/1000
# 60/60 [==============================] - 0s 505us/sample - loss: 0.3454 - mean_absolute_error: 0.5255 - val_loss: 0.2384 - val_mean_absolute_error: 0.4231
# Epoch 277/1000
# 60/60 [==============================] - 0s 300us/sample - loss: 0.3673 - mean_absolute_error: 0.5287 - val_loss: 0.2491 - val_mean_absolute_error: 0.4409
# Epoch 278/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.3495 - mean_absolute_error: 0.5278 - val_loss: 0.2500 - val_mean_absolute_error: 0.4267
# Epoch 279/1000
# ...
# 60/60 [==============================] - 0s 543us/sample - loss: 0.1488 - mean_absolute_error: 0.3086 - val_loss: 0.1777 - val_mean_absolute_error: 0.3211
# Epoch 908/1000
# 60/60 [==============================] - 0s 405us/sample - loss: 0.1586 - mean_absolute_error: 0.3066 - val_loss: 0.1767 - val_mean_absolute_error: 0.3017
# Epoch 909/1000
# 60/60 [==============================] - 0s 490us/sample - loss: 0.1541 - mean_absolute_error: 0.3111 - val_loss: 0.2599 - val_mean_absolute_error: 0.4172
# Epoch 910/1000
# 60/60 [==============================] - 0s 436us/sample - loss: 0.1641 - mean_absolute_error: 0.3181 - val_loss: 0.1860 - val_mean_absolute_error: 0.3100
# Epoch 911/1000
# 60/60 [==============================] - 0s 348us/sample - loss: 0.2783 - mean_absolute_error: 0.4219 - val_loss: 0.2006 - val_mean_absolute_error: 0.3500
# Epoch 912/1000
# 60/60 [==============================] - 0s 432us/sample - loss: 0.1896 - mean_absolute_error: 0.3302 - val_loss: 0.2011 - val_mean_absolute_error: 0.3509
# Epoch 913/1000
# 60/60 [==============================] - 0s 530us/sample - loss: 0.1717 - mean_absolute_error: 0.3198 - val_loss: 0.1775 - val_mean_absolute_error: 0.3005
# Epoch 914/1000
# 60/60 [==============================] - 0s 409us/sample - loss: 0.1753 - mean_absolute_error: 0.3355 - val_loss: 0.2239 - val_mean_absolute_error: 0.3367
# Epoch 915/1000
# 60/60 [==============================] - 0s 374us/sample - loss: 0.1592 - mean_absolute_error: 0.2996 - val_loss: 0.2005 - val_mean_absolute_error: 0.3176
# Epoch 916/1000
# 60/60 [==============================] - 0s 335us/sample - loss: 0.1426 - mean_absolute_error: 0.3027 - val_loss: 0.1680 - val_mean_absolute_error: 0.3046
# Epoch 917/1000
# 60/60 [==============================] - 0s 336us/sample - loss: 0.1464 - mean_absolute_error: 0.3024 - val_loss: 0.1758 - val_mean_absolute_error: 0.3193
# Epoch 918/1000
# 60/60 [==============================] - 0s 538us/sample - loss: 0.1642 - mean_absolute_error: 0.3147 - val_loss: 0.1942 - val_mean_absolute_error: 0.3156
# Epoch 919/1000
# 60/60 [==============================] - 0s 354us/sample - loss: 0.1492 - mean_absolute_error: 0.3055 - val_loss: 0.1730 - val_mean_absolute_error: 0.3140
# Epoch 920/1000
# 60/60 [==============================] - 0s 317us/sample - loss: 0.1474 - mean_absolute_error: 0.3059 - val_loss: 0.2065 - val_mean_absolute_error: 0.3220
# Epoch 921/1000
# 60/60 [==============================] - 0s 345us/sample - loss: 0.1912 - mean_absolute_error: 0.3378 - val_loss: 0.1954 - val_mean_absolute_error: 0.3416
# Epoch 922/1000
# 60/60 [==============================] - 0s 411us/sample - loss: 0.1810 - mean_absolute_error: 0.3202 - val_loss: 0.1737 - val_mean_absolute_error: 0.3160
# Epoch 923/1000
# 60/60 [==============================] - 0s 318us/sample - loss: 0.1404 - mean_absolute_error: 0.2945 - val_loss: 0.1691 - val_mean_absolute_error: 0.2956
# Epoch 924/1000
# 60/60 [==============================] - 0s 595us/sample - loss: 0.1530 - mean_absolute_error: 0.3181 - val_loss: 0.1672 - val_mean_absolute_error: 0.3034
# Epoch 925/1000
# 60/60 [==============================] - 0s 399us/sample - loss: 0.1433 - mean_absolute_error: 0.3095 - val_loss: 0.1735 - val_mean_absolute_error: 0.2973
# Epoch 926/1000
# 60/60 [==============================] - 0s 321us/sample - loss: 0.1415 - mean_absolute_error: 0.3044 - val_loss: 0.1808 - val_mean_absolute_error: 0.3230
# Epoch 927/1000
# 60/60 [==============================] - 0s 339us/sample - loss: 0.1779 - mean_absolute_error: 0.3347 - val_loss: 0.1697 - val_mean_absolute_error: 0.3046
# Epoch 928/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.1597 - mean_absolute_error: 0.3111 - val_loss: 0.2482 - val_mean_absolute_error: 0.4055
# Epoch 929/1000
# 60/60 [==============================] - 0s 404us/sample - loss: 0.1755 - mean_absolute_error: 0.3207 - val_loss: 0.1682 - val_mean_absolute_error: 0.2987
# Epoch 930/1000
# 60/60 [==============================] - 0s 328us/sample - loss: 0.1388 - mean_absolute_error: 0.2959 - val_loss: 0.1978 - val_mean_absolute_error: 0.3151
# Epoch 931/1000
# 60/60 [==============================] - 0s 354us/sample - loss: 0.1534 - mean_absolute_error: 0.3075 - val_loss: 0.1825 - val_mean_absolute_error: 0.3035
# Epoch 932/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.1451 - mean_absolute_error: 0.3048 - val_loss: 0.1766 - val_mean_absolute_error: 0.2980
# Epoch 933/1000
# 60/60 [==============================] - 0s 393us/sample - loss: 0.1420 - mean_absolute_error: 0.3054 - val_loss: 0.1876 - val_mean_absolute_error: 0.3066
# Epoch 934/1000
# 60/60 [==============================] - 0s 360us/sample - loss: 0.1408 - mean_absolute_error: 0.3011 - val_loss: 0.1945 - val_mean_absolute_error: 0.3386
# Epoch 935/1000
# 60/60 [==============================] - 0s 379us/sample - loss: 0.1715 - mean_absolute_error: 0.3215 - val_loss: 0.1703 - val_mean_absolute_error: 0.2983
# Epoch 936/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.1428 - mean_absolute_error: 0.3004 - val_loss: 0.1698 - val_mean_absolute_error: 0.2995
# Epoch 937/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.1392 - mean_absolute_error: 0.2982 - val_loss: 0.2295 - val_mean_absolute_error: 0.3367
# Epoch 938/1000
# 60/60 [==============================] - 0s 411us/sample - loss: 0.1482 - mean_absolute_error: 0.3006 - val_loss: 0.1772 - val_mean_absolute_error: 0.2979
# Epoch 939/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.1445 - mean_absolute_error: 0.3038 - val_loss: 0.1844 - val_mean_absolute_error: 0.3011
# Epoch 940/1000
# 60/60 [==============================] - 0s 617us/sample - loss: 0.1720 - mean_absolute_error: 0.3303 - val_loss: 0.1721 - val_mean_absolute_error: 0.3030
# Epoch 941/1000
# 60/60 [==============================] - 0s 495us/sample - loss: 0.1406 - mean_absolute_error: 0.2958 - val_loss: 0.1825 - val_mean_absolute_error: 0.3228
# Epoch 942/1000
# 60/60 [==============================] - 0s 413us/sample - loss: 0.1563 - mean_absolute_error: 0.3192 - val_loss: 0.1743 - val_mean_absolute_error: 0.2964
# Epoch 943/1000
# 60/60 [==============================] - 0s 421us/sample - loss: 0.1377 - mean_absolute_error: 0.2972 - val_loss: 0.1728 - val_mean_absolute_error: 0.3053
# Epoch 944/1000
# 60/60 [==============================] - 0s 418us/sample - loss: 0.1462 - mean_absolute_error: 0.2996 - val_loss: 0.1806 - val_mean_absolute_error: 0.3202
# Epoch 945/1000
# 60/60 [==============================] - 0s 328us/sample - loss: 0.1598 - mean_absolute_error: 0.3120 - val_loss: 0.2129 - val_mean_absolute_error: 0.3622
# Epoch 946/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.2551 - mean_absolute_error: 0.3986 - val_loss: 0.2114 - val_mean_absolute_error: 0.3246
# Epoch 947/1000
# 60/60 [==============================] - 0s 322us/sample - loss: 0.1466 - mean_absolute_error: 0.3019 - val_loss: 0.1773 - val_mean_absolute_error: 0.2988
# Epoch 948/1000
# 60/60 [==============================] - 0s 323us/sample - loss: 0.1384 - mean_absolute_error: 0.2991 - val_loss: 0.1704 - val_mean_absolute_error: 0.2956
# Epoch 949/1000
# 60/60 [==============================] - 0s 348us/sample - loss: 0.1688 - mean_absolute_error: 0.3278 - val_loss: 0.2059 - val_mean_absolute_error: 0.3537
# Epoch 950/1000
# 60/60 [==============================] - 0s 356us/sample - loss: 0.1907 - mean_absolute_error: 0.3589 - val_loss: 0.2085 - val_mean_absolute_error: 0.3198
# Epoch 951/1000
# 60/60 [==============================] - 0s 401us/sample - loss: 0.2104 - mean_absolute_error: 0.3639 - val_loss: 0.1993 - val_mean_absolute_error: 0.3458
# Epoch 952/1000
# 60/60 [==============================] - 0s 566us/sample - loss: 0.1553 - mean_absolute_error: 0.3086 - val_loss: 0.2036 - val_mean_absolute_error: 0.3146
# Epoch 953/1000
# 60/60 [==============================] - 0s 480us/sample - loss: 0.1612 - mean_absolute_error: 0.3184 - val_loss: 0.1788 - val_mean_absolute_error: 0.3190
# Epoch 954/1000
# 60/60 [==============================] - 0s 338us/sample - loss: 0.2109 - mean_absolute_error: 0.3690 - val_loss: 0.2015 - val_mean_absolute_error: 0.3144
# Epoch 955/1000
# 60/60 [==============================] - 0s 329us/sample - loss: 0.2042 - mean_absolute_error: 0.3542 - val_loss: 0.1869 - val_mean_absolute_error: 0.3299
# Epoch 956/1000
# 60/60 [==============================] - 0s 322us/sample - loss: 0.1673 - mean_absolute_error: 0.3245 - val_loss: 0.1725 - val_mean_absolute_error: 0.2942
# Epoch 957/1000
# 60/60 [==============================] - 0s 331us/sample - loss: 0.1436 - mean_absolute_error: 0.2948 - val_loss: 0.1722 - val_mean_absolute_error: 0.2933
# Epoch 958/1000
# 60/60 [==============================] - 0s 414us/sample - loss: 0.1774 - mean_absolute_error: 0.3361 - val_loss: 0.1829 - val_mean_absolute_error: 0.3248
# Epoch 959/1000
# 60/60 [==============================] - 0s 332us/sample - loss: 0.1876 - mean_absolute_error: 0.3288 - val_loss: 0.2052 - val_mean_absolute_error: 0.3543
# Epoch 960/1000
# 60/60 [==============================] - 0s 371us/sample - loss: 0.2123 - mean_absolute_error: 0.3722 - val_loss: 0.2310 - val_mean_absolute_error: 0.3345
# Epoch 961/1000
# 60/60 [==============================] - 0s 412us/sample - loss: 0.2136 - mean_absolute_error: 0.3650 - val_loss: 0.1887 - val_mean_absolute_error: 0.3332
# Epoch 962/1000
# 60/60 [==============================] - 0s 477us/sample - loss: 0.1782 - mean_absolute_error: 0.3308 - val_loss: 0.1857 - val_mean_absolute_error: 0.3036
# Epoch 963/1000
# 60/60 [==============================] - 0s 341us/sample - loss: 0.1709 - mean_absolute_error: 0.3160 - val_loss: 0.2403 - val_mean_absolute_error: 0.3454
# Epoch 964/1000
# 60/60 [==============================] - 0s 458us/sample - loss: 0.1964 - mean_absolute_error: 0.3405 - val_loss: 0.1807 - val_mean_absolute_error: 0.3248
# Epoch 965/1000
# 60/60 [==============================] - 0s 329us/sample - loss: 0.1504 - mean_absolute_error: 0.3086 - val_loss: 0.1801 - val_mean_absolute_error: 0.2993
# Epoch 966/1000
# 60/60 [==============================] - 0s 343us/sample - loss: 0.1416 - mean_absolute_error: 0.3075 - val_loss: 0.1673 - val_mean_absolute_error: 0.2960
# Epoch 967/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.1775 - mean_absolute_error: 0.3051 - val_loss: 0.1706 - val_mean_absolute_error: 0.2933
# Epoch 968/1000
# 60/60 [==============================] - 0s 374us/sample - loss: 0.1762 - mean_absolute_error: 0.3350 - val_loss: 0.2178 - val_mean_absolute_error: 0.3727
# Epoch 969/1000
# 60/60 [==============================] - 0s 337us/sample - loss: 0.2098 - mean_absolute_error: 0.3648 - val_loss: 0.1687 - val_mean_absolute_error: 0.2910
# Epoch 970/1000
# 60/60 [==============================] - 0s 369us/sample - loss: 0.1484 - mean_absolute_error: 0.2982 - val_loss: 0.1732 - val_mean_absolute_error: 0.2930
# Epoch 971/1000
# 60/60 [==============================] - 0s 344us/sample - loss: 0.1452 - mean_absolute_error: 0.3029 - val_loss: 0.1653 - val_mean_absolute_error: 0.2950
# Epoch 972/1000
# 60/60 [==============================] - 0s 375us/sample - loss: 0.1396 - mean_absolute_error: 0.2908 - val_loss: 0.1667 - val_mean_absolute_error: 0.2955
# Epoch 973/1000
# 60/60 [==============================] - 0s 620us/sample - loss: 0.1352 - mean_absolute_error: 0.2964 - val_loss: 0.1752 - val_mean_absolute_error: 0.2931
# Epoch 974/1000
# 60/60 [==============================] - 0s 466us/sample - loss: 0.1378 - mean_absolute_error: 0.2980 - val_loss: 0.1679 - val_mean_absolute_error: 0.2950
# Epoch 975/1000
# 60/60 [==============================] - 0s 449us/sample - loss: 0.1351 - mean_absolute_error: 0.2909 - val_loss: 0.1713 - val_mean_absolute_error: 0.3065
# Epoch 976/1000
# 60/60 [==============================] - 0s 542us/sample - loss: 0.1739 - mean_absolute_error: 0.3378 - val_loss: 0.3119 - val_mean_absolute_error: 0.4114
# Epoch 977/1000
# 60/60 [==============================] - 0s 395us/sample - loss: 0.2016 - mean_absolute_error: 0.3245 - val_loss: 0.1938 - val_mean_absolute_error: 0.3391
# Epoch 978/1000
# 60/60 [==============================] - 0s 494us/sample - loss: 0.1710 - mean_absolute_error: 0.3149 - val_loss: 0.2781 - val_mean_absolute_error: 0.3804
# Epoch 979/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.1591 - mean_absolute_error: 0.3079 - val_loss: 0.1665 - val_mean_absolute_error: 0.2999
# Epoch 980/1000
# 60/60 [==============================] - 0s 328us/sample - loss: 0.1523 - mean_absolute_error: 0.3083 - val_loss: 0.1663 - val_mean_absolute_error: 0.2952
# Epoch 981/1000
# 60/60 [==============================] - 0s 369us/sample - loss: 0.1347 - mean_absolute_error: 0.2944 - val_loss: 0.1666 - val_mean_absolute_error: 0.2952
# Epoch 982/1000
# 60/60 [==============================] - 0s 365us/sample - loss: 0.1359 - mean_absolute_error: 0.2886 - val_loss: 0.2223 - val_mean_absolute_error: 0.3268
# Epoch 983/1000
# 60/60 [==============================] - 0s 324us/sample - loss: 0.1538 - mean_absolute_error: 0.3012 - val_loss: 0.2007 - val_mean_absolute_error: 0.3097
# Epoch 984/1000
# 60/60 [==============================] - 0s 358us/sample - loss: 0.2265 - mean_absolute_error: 0.3647 - val_loss: 0.3207 - val_mean_absolute_error: 0.4140
# Epoch 985/1000
# 60/60 [==============================] - 0s 386us/sample - loss: 0.2369 - mean_absolute_error: 0.3878 - val_loss: 0.1680 - val_mean_absolute_error: 0.3014
# Epoch 986/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.1512 - mean_absolute_error: 0.3102 - val_loss: 0.1652 - val_mean_absolute_error: 0.2879
# Epoch 987/1000
# 60/60 [==============================] - 0s 327us/sample - loss: 0.1322 - mean_absolute_error: 0.2892 - val_loss: 0.1647 - val_mean_absolute_error: 0.2908
# Epoch 988/1000
# 60/60 [==============================] - 0s 432us/sample - loss: 0.1565 - mean_absolute_error: 0.3117 - val_loss: 0.1700 - val_mean_absolute_error: 0.2882
# Epoch 989/1000
# 60/60 [==============================] - 0s 343us/sample - loss: 0.1377 - mean_absolute_error: 0.2980 - val_loss: 0.1656 - val_mean_absolute_error: 0.2946
# Epoch 990/1000
# 60/60 [==============================] - 0s 314us/sample - loss: 0.1337 - mean_absolute_error: 0.2845 - val_loss: 0.1776 - val_mean_absolute_error: 0.2922
# Epoch 991/1000
# 60/60 [==============================] - 0s 390us/sample - loss: 0.1401 - mean_absolute_error: 0.2972 - val_loss: 0.1916 - val_mean_absolute_error: 0.3053
# Epoch 992/1000
# 60/60 [==============================] - 0s 427us/sample - loss: 0.2479 - mean_absolute_error: 0.3831 - val_loss: 0.2010 - val_mean_absolute_error: 0.3496
# Epoch 993/1000
# 60/60 [==============================] - 0s 478us/sample - loss: 0.2367 - mean_absolute_error: 0.3852 - val_loss: 0.1772 - val_mean_absolute_error: 0.2913
# Epoch 994/1000
# 60/60 [==============================] - 0s 374us/sample - loss: 0.1334 - mean_absolute_error: 0.2848 - val_loss: 0.1780 - val_mean_absolute_error: 0.3187
# Epoch 995/1000
# 60/60 [==============================] - 0s 347us/sample - loss: 0.1324 - mean_absolute_error: 0.2776 - val_loss: 0.1707 - val_mean_absolute_error: 0.2881
# Epoch 996/1000
# 60/60 [==============================] - 0s 366us/sample - loss: 0.1397 - mean_absolute_error: 0.2963 - val_loss: 0.1698 - val_mean_absolute_error: 0.3028
# Epoch 997/1000
# 60/60 [==============================] - 0s 346us/sample - loss: 0.1476 - mean_absolute_error: 0.2993 - val_loss: 0.1989 - val_mean_absolute_error: 0.3454
# Epoch 998/1000
# 60/60 [==============================] - 0s 382us/sample - loss: 0.1477 - mean_absolute_error: 0.2882 - val_loss: 0.1705 - val_mean_absolute_error: 0.3065
# Epoch 999/1000
# 60/60 [==============================] - 0s 376us/sample - loss: 0.1948 - mean_absolute_error: 0.3313 - val_loss: 0.1644 - val_mean_absolute_error: 0.2879
# Epoch 1000/1000
# 60/60 [==============================] - 0s 352us/sample - loss: 0.1306 - mean_absolute_error: 0.2848 - val_loss: 0.1645 - val_mean_absolute_error: 0.2915
# elapsed : 29.710477590560913

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# ## model.fit()의 validation_split
#
# 따로 validation 데이터를 주지 않고, test 데이터로 준 것의 일부를 validation에 사용.
#
# validation에 사용된 데이터는 학습에 사용되지 않는다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20, validation_split=0.1)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_27"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_90 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_91 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_92 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 13.028645753860474

# %%
plt.plot(history.history['loss'], label='loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()

# %% [markdown]
# # 데이터 크기와 epoch 수

# %%
# (train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.0001)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=5, verbose=2, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))
# Out:
# Model: "sequential_28"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_93 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_94 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_95 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 - 6s - loss: 0.2420 - mean_absolute_error: 0.4028
# Epoch 2/5
# 60000/60000 - 5s - loss: 0.1191 - mean_absolute_error: 0.2378
# Epoch 3/5
# 60000/60000 - 5s - loss: 0.0995 - mean_absolute_error: 0.2095
# Epoch 4/5
# 60000/60000 - 5s - loss: 0.0834 - mean_absolute_error: 0.1901
# Epoch 5/5
# 60000/60000 - 5s - loss: 0.0661 - mean_absolute_error: 0.1694
# elapsed : 28.110307216644287

# %%
y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()

# %% [markdown]
# train_x의 데이터 수가 6000개. epoch는 5. 총 30,000번 업데이트 되었다.
#
#
# epoch가 적어도 데이터 수가 많으면 학습 잘된다.

# %% [markdown]
# # Shuffle

# %% [markdown]
# ## 전체 데이터 준비 시에

# %%
x = np.arange(0,10,0.1)
# np.random.shuffle(x) # COMMENTED
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=2000, verbose=0, batch_size=20)

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_16 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# train 데이터와 test 데이터가 서로 떨어져 있다.
#
# train 영역의 데이터로 학습된 모델은 test 영역의 데이터에 적용하지 못한다.
#
# 전체데이터를 잘 섞어 주고, 이를 train, test로 나누어야 한다.

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x) # UNCOMMENT
y = np.sin(x)

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")
# Out:
# 60

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

history = model.fit(train_x, train_y, epochs=2000, verbose=0, batch_size=20)

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_20 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 학습 진행 시에
#
# 학습 시에 데이터를 섞어 주지 않으면 특정 데이터 순서로 학습이 일어나 편향이 생길 수있다.

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start_time = time.time()
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_96 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_97 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_98 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.6757636070251465

# %%
model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start_time = time.time()
# history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20, shuffle=True)
print("elapsed : {}".format(time.time() - start_time)) 

y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_30"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_99 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_100 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_101 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 3.753988027572632

# %% [markdown]
# 각 epoch마다 섞어 주는 거싱 중요하다.
#
# shuffle 파라매터의 디펄트 값은 True로, Keras의 model.fit() 호출시에는 따로 설정하지 않아도 된다.

# %% [markdown]
# # 모델 저장과 로딩

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 10)                20
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 7.178815841674805
# 40/40 [==============================] - 0s 533us/sample - loss: 0.3262 - mean_absolute_error: 0.5094
# loss= 0.32618337869644165
# mae= 0.50944674

# %% [markdown]
# 모델 저장

# %%
model.save('my_model.h5')

# !ls -al
# Out:
# total 40
# drwxr-xr-x 1 root root  4096 Jul 14 23:09 .
# drwxr-xr-x 1 root root  4096 Jul 14 22:41 ..
# drwxr-xr-x 4 root root  4096 Jul  1 13:41 .config
# -rw-r--r-- 1 root root 20744 Jul 14 23:13 my_model.h5
# drwxr-xr-x 1 root root  4096 Jul  1 13:42 sample_data

# %% [markdown]
# 모델 로딩

# %%
new_model = keras.models.load_model('my_model.h5')

y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ## TensorFlow 포멧의 저장과 로딩

# %%
keras.experimental.export_saved_model(model, 'model_path')

# !ls -al
# !ls -al model_path

new_model = keras.experimental.load_from_saved_model('model_path')


y_ = new_model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# WARNING:tensorflow:From <ipython-input-10-f0c3e8f608f4>:1: export_saved_model (from tensorflow.python.keras.saving.saved_model_experimental) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `model.save(..., save_format="tf")` or `tf.keras.models.save_model(..., save_format="tf")`.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/saved_model/signature_def_utils_impl.py:253: build_tensor_info (from tensorflow.python.saved_model.utils_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This function will only be available through the v1 compatibility library as tf.compat.v1.saved_model.utils.build_tensor_info or tf.compat.v1.saved_model.build_tensor_info.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: ['train']
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: None
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: ['eval']
# WARNING:tensorflow:Export includes no default signature!
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default']
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:No assets to save.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: model_path/saved_model.pb
# total 44
# drwxr-xr-x 1 root root  4096 Jul 14 23:14 .
# drwxr-xr-x 1 root root  4096 Jul 14 22:41 ..
# drwxr-xr-x 4 root root  4096 Jul  1 13:41 .config
# drwxr-xr-x 4 root root  4096 Jul 14 23:14 model_path
# -rw-r--r-- 1 root root 20744 Jul 14 23:13 my_model.h5
# drwxr-xr-x 1 root root  4096 Jul  1 13:42 sample_data
# total 120
# drwxr-xr-x 4 root root   4096 Jul 14 23:14 .
# drwxr-xr-x 1 root root   4096 Jul 14 23:14 ..
# drwxr-xr-x 2 root root   4096 Jul 14 23:14 assets
# -rw-r--r-- 1 root root 106257 Jul 14 23:14 saved_model.pb
# drwxr-xr-x 2 root root   4096 Jul 14 23:14 variables
# WARNING:tensorflow:From <ipython-input-10-f0c3e8f608f4>:6: load_from_saved_model (from tensorflow.python.keras.saving.saved_model_experimental) is deprecated and will be removed in a future version.
# Instructions for updating:
# The experimental save and load functions have been  deprecated. Please switch to `tf.keras.models.load_model`.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.

# %% [markdown]
# # GPU 사용
#
# 따로 명시하지 않아도 default로 GPU를 사용한다.
#
# 명시적으로 설정할 수도 있다.

# %% [markdown]
# ## 리스트 보기

# %%
from tensorflow.python.client import device_lib
print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %% [markdown]
# ## NVIDIA GPU 상태 보기

# %%
# !nvidia-smi
# Out:
# Wed Jul 14 03:49:50 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.42.01    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   51C    P0    28W /  70W |    282MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## GPU 설정
#
# 다음의 디바이스 이름이 가능
#
# - /device:GPU:0
# - /GPU:0
# - /gpu:0
# - /gpu
# - /cpu:0
# - /cpu

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.01)

# %%
with tf.device('/device:GPU:0'): # ADDED

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.momentum
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/alpha/guide/checkpoints#loading_mechanics for details.
# Model: "sequential_34"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_111 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_112 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_113 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.733446836471558

# %%
# with tf.device('/GPU:0'):
with tf.device('/CPU:0'):

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
  model.summary()

  start_time = time.time()
  history = model.fit(train_x, train_y, epochs=50, verbose=0, batch_size=20)
  print("elapsed : {}".format(time.time() - start_time)) 

  y_ = model.predict(test_x)

  plt.scatter(test_x,test_y)
  plt.scatter(test_x,y_,color='r')
  plt.show()
# Out:
# Model: "sequential_39"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_126 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_127 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_128 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 2.9162704944610596

# %% [markdown]
# # Overfitting 처리
#
# - DropOut
# - BatchNormalization
# - Regularization

# %%
from sklearn.datasets import make_moons
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from matplotlib import pyplot
from pandas import DataFrame

x, y = make_moons(n_samples=100, noise=0.2, random_state=32)

df = DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

split_index = int(len(x)*0.3)
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
model = Sequential()
model.add(Dense(20, input_shape=(2,), activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/nn_impl.py:183: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %% [markdown]
# ## DropOut

# %%
from tensorflow.keras.layers import Dropout

# %%
model = Sequential()
model.add(Dense(20, input_shape=(2,), activation='relu'))
model.add(Dropout(0.2)) # ADDED
model.add(Dense(20, activation='relu'))
model.add(Dropout(0.2)) # ADDED
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## BatchNormalization

# %%
from tensorflow.keras.layers import BatchNormalization

# %%
model = Sequential()
model.add(Dense(20, input_shape=(2,), activation='relu'))
model.add(BatchNormalization()) # ADDED
model.add(Dense(20, activation='relu'))
model.add(BatchNormalization()) # ADDED
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## Regularization
#
# Dense() 생성시에 kernel_regularization, bias_regularization으로 설정한다.
#
# - l1()
# - l1_l2()
# - l2()

# %%
from tensorflow.keras.regularizers import l1, l2

# %%
model = Sequential()
# model.add(Dense(20, input_shape=(2,), activation='relu'))
# model.add(Dense(20, activation='relu'))
model.add(Dense(20, input_shape=(2,), activation='relu', kernel_regularizer=l2(0.001) ))
model.add(Dense(20, activation='relu', kernel_regularizer=l2(0.001)))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## 전부다

# %%
model = Sequential()
model.add(Dense(20, input_shape=(2,), activation='relu', kernel_regularizer=l2(0.001) ))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(20, activation='relu', kernel_regularizer=l2(0.001)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# ## 데이터를 10배로

# %%
from sklearn.datasets import make_moons
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from matplotlib import pyplot
from pandas import DataFrame

# x, y = make_moons(n_samples=100, noise=0.2, random_state=32)
x, y = make_moons(n_samples=100*10, noise=0.2, random_state=32)

df = DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

split_index = int(len(x)*0.3)
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
model = Sequential()
model.add(Dense(20, input_shape=(2,), activation='relu'))
model.add(Dense(20, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

history = model.fit(train_x, train_y, batch_size=100, validation_data=(test_x, test_y), epochs=2000, verbose=0)

pyplot.plot(history.history['loss'], label='train_loss')
pyplot.plot(history.history['val_loss'], label='val_loss')
pyplot.legend()
pyplot.show()

# %% [markdown]
# # 웨이트 초기값
#
# Dense() 생성시에 kernel_initializer, bias_initializer로 설정한다.
#
# - 'he_normal'
# - 'lecun_normal'

# %%
(train_x, train_y), (test_x, test_y) = get_sin_data(start=0, end=10, step=0.1)

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
# model.add(Dense(10, activation='tanh'))
model.add(Dense(10, activation='tanh', input_shape=(1,), kernel_initializer='he_normal'))
model.add(Dense(10, activation='tanh', kernel_initializer='he_normal'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


y_ = model.predict(test_x)

plt.scatter(test_x,test_y)
plt.scatter(test_x,y_,color='r')
plt.show()
# Out:
# Model: "sequential_48"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_153 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_154 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_155 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 9.899303913116455
# 40/40 [==============================] - 0s 6ms/sample - loss: 0.1786 - mean_absolute_error: 0.3478
# loss= 0.1785893499851227
# mae= 0.34776106

# %% [markdown]
# # 노이즈

# %%
def train_sin_with_noise(noise_size):

  # x = np.arange(0,10,0.1)
  x = np.arange(0,10,0.001)
  np.random.shuffle(x)
  y = np.sin(x)

  noiseless_y = np.copy(y) # ADD
  y = y + np.random.rand(y.shape[0])*noise_size - noise_size/2.0 # ADD

  split_index = int(x.shape[0]*0.6)

  train_x, test_x = x[:split_index], x[split_index:]
  train_y, test_y = y[:split_index], y[split_index:]
  test_noiseless_y = noiseless_y[split_index:] # ADD

  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
  model.summary()


  start_time = time.time()
  model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=100)
  print("elapsed : {}".format(time.time() - start_time))    


  loss, mae = model.evaluate(test_x, test_y)
  print("loss=", loss)
  print("mae=", mae)


  y_ = model.predict(test_x)

  # plt.scatter(test_x,test_y)
  plt.scatter(test_x,test_y, s=1)
  plt.scatter(test_x,y_, s=1)
  plt.show()

# %% [markdown]
# ## 노이즈 없을 때

# %%
train_sin_with_noise(0.0)
# Out:
# Model: "sequential_49"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_156 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_157 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_158 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 132.20434427261353
# 4000/4000 [==============================] - 0s 112us/sample - loss: 3.6569e-05 - mean_absolute_error: 0.0048
# loss= 3.656883799703792e-05
# mae= 0.004837465

# %% [markdown]
# ## 노이즈 크기 0.1

# %%
train_sin_with_noise(0.1)
# Out:
# Model: "sequential_50"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_159 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_160 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_161 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 133.93566060066223
# 4000/4000 [==============================] - 1s 175us/sample - loss: 0.0026 - mean_absolute_error: 0.0400
# loss= 0.0026135940691456197
# mae= 0.04000606

# %% [markdown]
# ## 노이즈 크기 0.5

# %%
train_sin_with_noise(0.5)
# Out:
# Model: "sequential_51"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_162 (Dense)            (None, 10)                20
# _________________________________________________________________
# dense_163 (Dense)            (None, 10)                110
# _________________________________________________________________
# dense_164 (Dense)            (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-80-7df57ce4ec47> in <module>()
# ----> 1 train_sin_with_noise(0.5)
#
# <ipython-input-77-8b581d9742b4> in train_sin_with_noise(noise_size)
#      26
#      27   start_time = time.time()
# ---> 28   model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=100)
#      29   print("elapsed : {}".format(time.time() - start_time))
#      30
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     725         max_queue_size=max_queue_size,
#     726         workers=workers,
# --> 727         use_multiprocessing=use_multiprocessing)
#     728
#     729   def evaluate(self,
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     673         validation_steps=validation_steps,
#     674         validation_freq=validation_freq,
# --> 675         steps_name='steps_per_epoch')
#     676
#     677   def evaluate(self,
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/engine/training_arrays.py in model_iteration(model, inputs, targets, sample_weights, batch_size, epochs, verbose, callbacks, val_inputs, val_targets, val_sample_weights, shuffle, initial_epoch, steps_per_epoch, validation_steps, validation_freq, mode, validation_in_fit, prepared_feed_values_from_dataset, steps_name, **kwargs)
#     392
#     393         # Get outputs.
# --> 394         batch_outs = f(ins_batch)
#     395         if not isinstance(batch_outs, list):
#     396           batch_outs = [batch_outs]
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in __call__(self, inputs)
#    3439     inputs = nest.flatten(inputs, expand_composites=True)
#    3440
# -> 3441     session = get_session(inputs)
#    3442     feed_arrays = []
#    3443     array_vals = []
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in get_session(op_input_list)
#     484   if not _MANUAL_VAR_INIT:
#     485     with session.graph.as_default():
# --> 486       _initialize_variables(session)
#     487   return session
#     488
#
# /tensorflow-1.15.2/python3.7/tensorflow_core/python/keras/backend.py in _initialize_variables(session)
#     895   candidate_vars = []
#     896   for v in variables:
# --> 897     if not getattr(v, '_keras_initialized', False):
#     898       candidate_vars.append(v)
#     899   if candidate_vars:
#
# KeyboardInterrupt:

# %% [markdown]
# ## 노이즈 크기 1.0

# %%
train_sin_with_noise(1.0)

# %% [markdown]
# ## 노이즈 크기 10.0

# %%
train_sin_with_noise(10.0)

# %% [markdown]
# ## 노이즈 피쳐
# 노이즈 입력을 하나 더 준다.

# %%
x = np.arange(0,10,1.0)
np.random.shuffle(x)

y = np.zeros((x.shape[0],2))
y[:,0] = np.sin(x)
y[:,1] = np.random.rand(x.shape[0])

# %%
# x = np.arange(0,10,0.001)
x = np.zeros((10000,2))
x[:,0] = np.arange(0,10,0.001) # ADD
x[:,1] = np.random.rand(x.shape[0]) # ADD
np.random.shuffle(x)

# y = np.sin(x)
y = np.sin(x[:,0])

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))


model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()


start_time = time.time()
# model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
model.fit(train_x, train_y, epochs=100, verbose=1, batch_size=20)
print("elapsed : {}".format(time.time() - start_time))    


loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)


y_ = model.predict(test_x)

plt.scatter(test_x[:,0],test_y)
plt.scatter(test_x[:,0],y_,color='r')
plt.show()

# %% [markdown]
# # 학습 되지 않는 랜덤 함수
#
# 랜덤 한수의 경우 x와 y의 간에 관계가 없다.
#
# 입출력 간에 관계가 없는 함수로 학습되지 않는다.

# %%
x = np.arange(0,10,0.1)
np.random.shuffle(x)
# y = np.sin(x)
y = np.random.random_sample(x.shape[0])

split_index = int(x.shape[0]*0.6)
print(split_index)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]


plt.scatter(train_x, train_y)
plt.scatter(test_x, test_y, color="r")

# %% [markdown]
# # CallBack
#
# 학습 도중 로그 출력이나 모델저장 등 다양한 액션을 취할 수 있다.

# %%
import numpy as np
import matplotlib.pyplot as plt

from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense
from tensorflow.keras.callbacks import Callback

import time

# %%
x = np.arange(-1,1,0.01)
np.random.shuffle(x)
y = x**2

split_index = int(x.shape[0]*0.6)

train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
def train_with_callbacks(callbacks):

  # 모델 정의
  model = keras.Sequential()
  model.add(Dense(10, activation='tanh', input_shape=(1,)))
  model.add(Dense(10, activation='tanh'))
  model.add(Dense(1))


  # 모델 컴파일
  model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
  model.summary()


  # 학습
  start_time = time.time()
  model.fit(train_x, train_y, epochs=100, verbose=0, batch_size=20, validation_split=0.1, callbacks=callbacks)
  print("elapsed : {}".format(time.time() - start_time))

# %% [markdown]
# ## 모델 저장

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

model_check_point = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

train_with_callbacks([model_check_point])
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_17 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_18 (Dense)             (None, 1)                 11
# =================================================================
# Total params: 141
# Trainable params: 141
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 5.481262922286987

# %% [markdown]
# ## 로스 출력

# %%
# copy from https://gist.github.com/stared/dfb4dfaf6d9a8501cd1cc8b8cb806d2e

from IPython.display import clear_output
from tensorflow.keras.callbacks import Callback

class PlotLosses(Callback):

  def on_train_begin(self, logs={}):

    self.i = 0
    self.x = []
    self.losses = []
    self.val_losses = []

    self.fig = plt.figure()

    self.logs = []


  def on_epoch_end(self, epoch, logs={}):

    self.logs.append(logs)
    self.x.append(self.i)
    self.losses.append(logs.get('loss'))
    self.val_losses.append(logs.get('val_loss'))
    self.i += 1

    clear_output(wait=True)
    plt.plot(self.x, self.losses, label="loss")
    plt.plot(self.x, self.val_losses, label="val_loss")
    plt.legend()
    plt.show();
    print("loss = ", self.losses[-1], ", val_loss = ", self.val_losses[-1])

# %%
plot_losses = PlotLosses()

train_with_callbacks([plot_losses])
# Out:
# loss =  0.07658682018518448 , val_loss =  0.07498941570520401
# elapsed : 35.52447581291199

# %% [markdown]
# ## early stopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss',  # 모니터링 대상
                               mode='auto',         # 학습 방향을 자동으로 탐지
                               patience=50)         # 중지까지의 여유분

train_with_callbacks([early_stopping])

# %% [markdown]
# ## 학습율 조정
#
# 학습 과정을 모니터링 하면서 진척되지 않으면 학습율을 조정한다.

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

reduce_lr = ReduceLROnPlateau(monitor='val_loss', # 모니터링 대상
                              factor=0.2,         # 줄이는 양
                              patience=5,         # 대상 기간동안 유지
                              min_lr=0.001)       # 최소 학습율

train_with_callbacks([reduce_lr])

# %% [markdown]
# ## 모두 한번에

# %%
from sklearn.datasets import make_moons
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from matplotlib import pyplot
from pandas import DataFrame

x, y = make_moons(n_samples=100, noise=0.2, random_state=1)

df = DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = pyplot.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
pyplot.show()

split_index = 30
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

model = Sequential()
model.add(Dense(500, input_shape=(2,), activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])


model_check_point = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)
plot_losses = PlotLosses()
early_stopping = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.001)

callbacks = [model_check_point, plot_losses, early_stopping, reduce_lr]


# history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=500, verbose=0)
history = model.fit(train_x, train_y, validation_data=(test_x, test_y), epochs=500, verbose=0, callbacks=callbacks)


plt.plot(history.history['loss'], label='train_loss')
plt.plot(history.history['val_loss'], label='val_loss')
plt.legend()
plt.show()
# Out:
# loss =  0.09470715373754501 , val_loss =  0.3071187436580658

# %% [markdown]
# # Optimizer

# %%
from sklearn.datasets import make_moons
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Sequential
from pandas import DataFrame
import matplotlib.pyplot as plt

x, y = make_moons(n_samples=100, noise=0.1, random_state=1)

df = DataFrame(dict(x=x[:,0], y=x[:,1], label=y))
colors = {0:'red', 1:'blue'}
fig, ax = plt.subplots()
grouped = df.groupby('label')
for key, group in grouped:
    group.plot(ax=ax, kind='scatter', x='x', y='y', label=key, color=colors[key])
plt.show()

split_index = int(len(x)*0.7)
train_x, test_x = x[:split_index], x[split_index:]
train_y, test_y = y[:split_index], y[split_index:]

# %%
def train_with_optimizer(optimizer):
  
  model = Sequential()
  model.add(Dense(500, activation="relu", input_shape=(2,)))
  model.add(Dense(1, activation='sigmoid'))
  model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

  model.compile(optimizer=optimizer, loss="mse", metrics=["mae"])
  
  history = model.fit(train_x, train_y, epochs=100, verbose=0, batch_size=20, validation_split=0.1)

  plt.plot(history.history["loss"])
  plt.plot(history.history["val_loss"])
  plt.show()

# %% [markdown]
# ## SGD

# %%
optimizer = "SGD"

train_with_optimizer(optimizer)

# %%
from tensorflow.keras.optimizers import SGD

optimizer = SGD(learning_rate=0.001)

train_with_optimizer(optimizer)

# %% [markdown]
# ## Adam

# %%
optimizer = "Adam"

train_with_optimizer(optimizer)

# %%
from tensorflow.keras.optimizers import Adam

optimizer = Adam(learning_rate=0.01, beta_1=0.9, beta_2=0.999, epsilon=1e-07)

train_with_optimizer(optimizer)

# %% [markdown]
# ## Adagrad

# %%
optimizer = "Adagrad"

train_with_optimizer(optimizer)

# %%
from tensorflow.keras.optimizers import Adagrad

optimizer = Adagrad(learning_rate=0.01, epsilon=1e-06)

train_with_optimizer(optimizer)

# %% [markdown]
# ## RMSprop

# %%
optimizer = "RMSprop"

train_with_optimizer(optimizer)

# %%
from tensorflow.keras.optimizers import RMSprop

optimizer = RMSprop(learning_rate=0.01, rho=0.9, decay=0.9)

train_with_optimizer(optimizer)

# %% [markdown]
# # 다양한 입출력

# %% [markdown]
# ## 2개의 입력, 1개의 출력
#
# x1 + x2 -> y의 함수를 학습
#
# x1과 x2는 0~1의 범위를 갖는다.

# %%
x = np.ones((100,2))
x[:,0] = np.random.rand(100)
x[:,1] = np.random.rand(100)
y = np.sum(x, axis=1)


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
model.add(Dense(1))

model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000*5, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)
              
y_ = model.predict(test_x)

# plt.scatter(test_x,test_y)
# plt.scatter(test_x,y_, color="r")
plt.scatter(test_x.T[0],test_y)
plt.scatter(test_x.T[0],y_, color="r")
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 32.96182060241699
# 40/40 [==============================] - 0s 681us/sample - loss: 3.4932e-04 - mean_absolute_error: 0.0119
# loss= 0.0003493173368042335
# mae= 0.01190992

# %% [markdown]
# ## 1개의 입력, 2개의 출력
#
# 다음과 같이 y는 2개의 값을 갖고, y1 = x*2, y2=x/2인 함수를 학습
#
# ```
# y1 = x*2.0
# y2 = x/2.0
# ```

# %%
x = np.random.rand(100)
y = np.zeros((100,2))
y[:,0] = x*2.0
y[:,1] = x/2.0


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)
              
y_ = model.predict(test_x)

plt.plot(test_y[:,0], 'o')
plt.plot(y_[:,0], 'o')
plt.show()

plt.plot(test_y[:,1], 'o')
plt.plot(y_[:,1], 'o')
plt.show()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_45 (Dense)             (None, 10)                20
# _________________________________________________________________
# dense_46 (Dense)             (None, 10)                110
# _________________________________________________________________
# dense_47 (Dense)             (None, 2)                 22
# =================================================================
# Total params: 152
# Trainable params: 152
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 11.090509176254272
# 40/40 [==============================] - 0s 3ms/sample - loss: 7.8118e-04 - mean_absolute_error: 0.0185
# loss= 0.000781180732883513
# mae= 0.01853835

# %% [markdown]
# ## 2개의 입력, 2개의 출력
#
# x1 + x2 -> z,
#
# y1 = z*2, y2=z/2인 함수를 학습
#
# x1과 x2는 0~1의 범위를 갖는다.

# %%
x = np.ones((100,2))
x[:,0] = np.random.rand(100)
x[:,1] = np.random.rand(100)

z = np.sum(x, axis=1)

y = np.zeros((100,2))
y[:,0] = z*2.0
y[:,1] = z/2.0


s = int(x.shape[0]*0.6)
train_x, test_x = x[:s], x[s:]
train_y, test_y = y[:s], y[s:]


from tensorflow.keras import optimizers
from tensorflow.keras.layers import Dense

model = keras.Sequential()
# model.add(Dense(10, activation='tanh', input_shape=(1,)))
model.add(Dense(10, activation='tanh', input_shape=(2,)))
model.add(Dense(10, activation='tanh'))
# model.add(Dense(1))
model.add(Dense(2))

model.compile(optimizer="SGD", loss="mse", metrics=["mae"])
model.summary()

start = time.time()
model.fit(train_x, train_y, epochs=1000, verbose=0, batch_size=20)
print("elapsed :", (time.time() - start))

loss, mae = model.evaluate(test_x, test_y)
print("loss=", loss)
print("mae=", mae)
              
y_ = model.predict(test_x)

plt.plot(test_y[:,0], 'o')
plt.plot(y_[:,0], 'o')
plt.show()

plt.plot(test_y[:,1], 'o')
plt.plot(y_[:,1], 'o')
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 10)                30
# _________________________________________________________________
# dense_4 (Dense)              (None, 10)                110
# _________________________________________________________________
# dense_5 (Dense)              (None, 2)                 22
# =================================================================
# Total params: 162
# Trainable params: 162
# Non-trainable params: 0
# _________________________________________________________________
# elapsed : 8.615222454071045
# 40/40 [==============================] - 0s 555us/sample - loss: 0.0017 - mean_absolute_error: 0.0284
# loss= 0.0016644120682030917
# mae= 0.02841103
