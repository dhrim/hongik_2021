# %% [markdown]
# # 얼굴 인식

# %% [markdown]
# copy from : https://github.com/santhalakshminarayana/face-recognition/blob/master/Face_Recognition.ipynb
#
# 아티클 : https://medium.com/analytics-vidhya/face-recognition-with-vgg-face-in-keras-96e6bc1951d5
#
#
# 얼굴 부분 추출과, 추출된 얼굴의 분류 2단계로 진행됨.
#
# 얼굴 추출은 이미 학습된 모델을 가져와서 추출하고, 추출된 부분을 별개의 파일로 저장.
#
# 별개의 파일로 저장된 얼굴 영상을 VGGFace 모델을 가져와서 feature를 추출함.
#
# 이렇게 추출한 feature를 입력으로 얼굴 분류 모델을 학습한다.

# %% [markdown]
# # 데이터 준비

# %% [markdown]
# ## 데이터 준비
#
# 아래와 같이 데이터를 준비한다.
# 반드시 확장자가 'jpg'이어야 한다.
#
# <br> face_data.zip으로 묶어서 구글드라이브의 tmp 폴더에 가져다 놓는다.
#
# ```
# face_data/
#   Images/
#     jobs_1.jpg
#     jobs_2.jpg
#     ...
#     faker_1.jpg
#     faker_2.jpg
#     ...
#     iu_1.jpg
#     iu_2.jpg
#   Test_images/
#     jobs_11.jpg
#     jobs_12.jpg
#     ...
#     faker_11.jpg
#     faker_12.jpg
#     ...
#     iu_11.jpg
#     iu_12.jpg
# ```

# %% [markdown]
# 구글 드라이브 마운트

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 혹시 기존에 파일들이 있으면 깔금히 지우고 시작

# %%
# %%shell
# rm -rf __MACOSX
# rm -rf face_data.zip
# rm -rf face_data

# %% [markdown]
# 구글 드라이브에서 colab 으로 파일 카피

# %%
# !cp '/content/drive/MyDrive/tmp/face_data.zip' ./

# %% [markdown]
# 압축 풀기

# %%
# !unzip face_data.zip
# Out:
# Archive:  face_data.zip
#    creating: face_data/
#   inflating: __MACOSX/._face_data
#    creating: face_data/Test_images/
#   inflating: __MACOSX/face_data/._Test_images
#    creating: face_data/Images/
#   inflating: __MACOSX/face_data/._Images
#   inflating: face_data/Test_images/.DS_Store
#   inflating: __MACOSX/face_data/Test_images/._.DS_Store
#   inflating: face_data/Test_images/jobs_28.jpg
#   inflating: __MACOSX/face_data/Test_images/._jobs_28.jpg
#   inflating: face_data/Test_images/faker_25.jpg
#   inflating: __MACOSX/face_data/Test_images/._faker_25.jpg
#   inflating: face_data/Test_images/faker_27.jpg
#   inflating: __MACOSX/face_data/Test_images/._faker_27.jpg
#   inflating: face_data/Test_images/faker_33.jpg
#   inflating: __MACOSX/face_data/Test_images/._faker_33.jpg
#   inflating: face_data/Test_images/faker_32.jpg
#   inflating: __MACOSX/face_data/Test_images/._faker_32.jpg
#   inflating: face_data/Test_images/son_17.jpg
#   inflating: __MACOSX/face_data/Test_images/._son_17.jpg
#   inflating: face_data/Test_images/iu_23.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_23.jpg
#   inflating: face_data/Test_images/son_16.jpg
#   inflating: __MACOSX/face_data/Test_images/._son_16.jpg
#   inflating: face_data/Test_images/iu_27.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_27.jpg
#   inflating: face_data/Test_images/iu_33.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_33.jpg
#   inflating: face_data/Test_images/iu_25.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_25.jpg
#   inflating: face_data/Test_images/iu_30.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_30.jpg
#   inflating: face_data/Test_images/iu_24.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_24.jpg
#   inflating: face_data/Test_images/iu_28.jpg
#   inflating: __MACOSX/face_data/Test_images/._iu_28.jpg
#   inflating: face_data/Test_images/son_20.jpg
#   inflating: __MACOSX/face_data/Test_images/._son_20.jpg
#   inflating: face_data/Test_images/son_18.jpg
#   inflating: __MACOSX/face_data/Test_images/._son_18.jpg
#   inflating: face_data/Test_images/son_19.jpg
#   inflating: __MACOSX/face_data/Test_images/._son_19.jpg
#   inflating: face_data/Test_images/jobs_32.jpg
#   inflating: __MACOSX/face_data/Test_images/._jobs
# Out:
# total 16
# drwxr-xr-x 4 root root 4096 Jun 22 11:12 .
# drwxr-xr-x 1 root root 4096 Dec  3 00:43 ..
# drwxr-xr-x 2 root root 4096 Dec  3 00:31 Images
# drwxr-xr-x 2 root root 4096 Dec  3 00:31 Test_images

# %% [markdown]
# 폴더 Images, Test_images가 있는 위치로 이동

# %%
# %cd $WORKING_PATH
# Out:
# /content/face_data

# %% [markdown]
# Images 폴더 안의 영상 파일이름을 구한다.

# %%
import os
import glob

TARGET_FOLDER_NAME = "Images"

image_path_names=[]
person_names=set()
for file_name in glob.glob(WORKING_PATH+'/'+TARGET_FOLDER_NAME+'/*_[1-9]*.jpg'):
  image_path_names.append(file_name)
  person_names.add(image_path_names[-1].split('/')[-1].split('_')[0])

# %% [markdown]
# 이미지 파일 갯수

# %%
len(image_path_names)
# Out:
# 54

# %% [markdown]
# 파일 이름들 보기

# %%
print(image_path_names)
# Out:
# ['/content/face_data/Images/son_12.jpg', '/content/face_data/Images/iu_17.jpg', '/content/face_data/Images/jobs_7.jpg', '/content/face_data/Images/jobs_24.jpg', '/content/face_data/Images/iu_5.jpg', '/content/face_data/Images/son_1.jpg', '/content/face_data/Images/iu_10.jpg', '/content/face_data/Images/faker_10.jpg', '/content/face_data/Images/son_11.jpg', '/content/face_data/Images/son_10.jpg', '/content/face_data/Images/faker_8.jpg', '/content/face_data/Images/jobs_17.jpg', '/content/face_data/Images/iu_12.jpg', '/content/face_data/Images/iu_22.jpg', '/content/face_data/Images/faker_3.jpg', '/content/face_data/Images/son_8.jpg', '/content/face_data/Images/faker_23.jpg', '/content/face_data/Images/son_15.jpg', '/content/face_data/Images/jobs_20.jpg', '/content/face_data/Images/faker_2.jpg', '/content/face_data/Images/faker_24.jpg', '/content/face_data/Images/jobs_9.jpg', '/content/face_data/Images/iu_21.jpg', '/content/face_data/Images/faker_9.jpg', '/content/face_data/Images/son_3.jpg', '/content/face_data/Images/faker_21.jpg', '/content/face_data/Images/faker_11.jpg', '/content/face_data/Images/son_7.jpg', '/content/face_data/Images/son_6.jpg', '/content/face_data/Images/iu_14.jpg', '/content/face_data/Images/faker_7.jpg', '/content/face_data/Images/jobs_26.jpg', '/content/face_data/Images/jobs_27.jpg', '/content/face_data/Images/iu_6.jpg', '/content/face_data/Images/jobs_8.jpg', '/content/face_data/Images/jobs_10.jpg', '/content/face_data/Images/son_14.jpg', '/content/face_data/Images/son_4.jpg', '/content/face_data/Images/son_2.jpg', '/content/face_data/Images/faker_15.jpg', '/content/face_data/Images/faker_1.jpg', '/content/face_data/Images/iu_2.jpg', '/content/face_data/Images/faker_16.jpg', '/content/face_data/Images/iu_16.jpg', '/content/face_data/Images/faker_18.jpg', '/content/face_data/Images/jobs_22.jpg', '/content/face_data/Images/iu_11.jpg', '/content/face_data/Images/iu_15.jpg', '/content/face_data/Images/faker_22.jpg', '/content/face_data/Images/son_5.jpg', '/content/face_data/Images/jobs_5.jpg', '/content/face_data/Images/iu_13.jpg', '/content/face_data/Images/jobs_12.jpg', '/content/face_data/Images/son_9.jpg']

# %% [markdown]
# 사람 이름 보기

# %%
print(person_names)
# Out:
# {'son', 'jobs', 'iu', 'faker'}

# %% [markdown]
# # 얼굴 분류를 위한 얼굴부분 데이터 만들기
#
# 얼굴 부분 탐지하여 crop한다.
#
#
# dlib의 face detector를 사용

# %% [markdown]
# face detector 모델을 다운로드

# %%
# Download Dlib CNN face detector
# !wget http://dlib.net/files/mmod_human_face_detector.dat.bz2
# Out:
# --2020-12-03 01:07:41--  http://dlib.net/files/mmod_human_face_detector.dat.bz2
# Resolving dlib.net (dlib.net)... 107.180.26.78
# Connecting to dlib.net (dlib.net)|107.180.26.78|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 694709 (678K)
# Saving to: ‘mmod_human_face_detector.dat.bz2’
#
# mmod_human_face_det 100%[===================>] 678.43K  1.19MB/s    in 0.6s
#
# 2020-12-03 01:07:42 (1.19 MB/s) - ‘mmod_human_face_detector.dat.bz2’ saved [694709/694709]

# %% [markdown]
# 압축 풀기

# %%
# !bzip2 -dk mmod_human_face_detector.dat.bz2

# %% [markdown]
# ## FaceDetector 로딩

# %%
import cv2
import matplotlib.pyplot as plt
import dlib

# %% [markdown]
# ## Images 폴더 파일들 crop
#
# Images 폴더의 파일들을 읽어 Images_crop에 생성

# %% [markdown]
# 모델 로딩

# %%
dnnFaceDetector=dlib.cnn_face_detection_model_v1("mmod_human_face_detector.dat")

# %% [markdown]
# 저장될 폴더 이름

# %%
CROP_OUTPUT_FOLDER_NAME = 'Images_crop'

# %% [markdown]
# crop되어 저장될 폴더 생성

# %%
 os.mkdir(WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME)

# %% [markdown]
# 각 카테고리 별 폴더 생성

# %%
# For each person create a separate folder
for person in person_names:
  os.mkdir(WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME+'/'+person+'/')

# %%
# !ls -al $CROP_OUTPUT_FOLDER_NAME
# Out:
# total 24
# drwxr-xr-x 6 root root 4096 Dec  3 01:08 .
# drwxr-xr-x 5 root root 4096 Dec  3 01:08 ..
# drwxr-xr-x 2 root root 4096 Dec  3 01:08 faker
# drwxr-xr-x 2 root root 4096 Dec  3 01:08 iu
# drwxr-xr-x 2 root root 4096 Dec  3 01:08 jobs
# drwxr-xr-x 2 root root 4096 Dec  3 01:08 son

# %%
TARGET_IMAGE_PATH_NAMES = image_path_names

for file_name in TARGET_IMAGE_PATH_NAMES:

  # 이미지 읽기
  img=cv2.imread(file_name)

  # 모델의 입력에 맞게 변환
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # 박스 검출
  rects=dnnFaceDetector(gray,1)

  # 검출된 박스에서 left, top, right, bottom 값 구하기
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
  if right==0: continue

  # width와 height 구하기
  width=right-left
  height=bottom-top

  # 이미지 crop
  img_crop=img[top:top+height,left:left+width]

  # 저장할 파일 이름 만들기
  img_path=WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME+'/'+file_name.split('/')[-1].split('_')[0]+'/'+file_name.split('/')[-1]
  # crop한 이미지를 파일로 쓰기
  cv2.imwrite(img_path,img_crop)

# %%
from IPython.display import Image
display(Image('Images/iu_10.jpg'))
display(Image('Images_crop/iu/iu_10.jpg'))

# %% [markdown]
# ## Test_Image 파일들 crop
#
# Test_Images의 파일들을 읽어 Test_Images_crop에 생성

# %% [markdown]
# Images 폴더 안의 영상 파일이름을 구한다.

# %%
import os
import glob

TARGET_FOLDER_NAME = "Test_images"

test_image_path_names=[]
for file_name in glob.glob(WORKING_PATH+'/'+TARGET_FOLDER_NAME+'/*_[1-9]*.jpg'):
  test_image_path_names.append(file_name)

# %% [markdown]
# 이미지 파일 갯수

# %%
len(test_image_path_names)
# Out:
# 24

# %% [markdown]
# 파일 이름들 보기

# %%
print(test_image_path_names)
# Out:
# ['/content/face_data/Test_images/faker_27.jpg', '/content/face_data/Test_images/son_16.jpg', '/content/face_data/Test_images/faker_25.jpg', '/content/face_data/Test_images/iu_23.jpg', '/content/face_data/Test_images/son_18.jpg', '/content/face_data/Test_images/iu_24.jpg', '/content/face_data/Test_images/son_20.jpg', '/content/face_data/Test_images/jobs_31.jpg', '/content/face_data/Test_images/iu_33.jpg', '/content/face_data/Test_images/jobs_28.jpg', '/content/face_data/Test_images/iu_27.jpg', '/content/face_data/Test_images/faker_32.jpg', '/content/face_data/Test_images/jobs_36.jpg', '/content/face_data/Test_images/faker_29.jpg', '/content/face_data/Test_images/faker_28.jpg', '/content/face_data/Test_images/son_19.jpg', '/content/face_data/Test_images/iu_28.jpg', '/content/face_data/Test_images/iu_30.jpg', '/content/face_data/Test_images/faker_33.jpg', '/content/face_data/Test_images/jobs_32.jpg', '/content/face_data/Test_images/jobs_30.jpg', '/content/face_data/Test_images/jobs_33.jpg', '/content/face_data/Test_images/son_17.jpg', '/content/face_data/Test_images/iu_25.jpg']

# %%
CROP_OUTPUT_FOLDER_NAME = 'Test_Images_crop'

# %% [markdown]
# crop되어 저장될 폴더 생성

# %%
os.mkdir(WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME)

# %% [markdown]
# 각 카테고리 별 폴더 생성

# %%
# For each person create a separate folder
for person in person_names:
  os.mkdir(WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME+'/'+person+'/')

# %%
# !ls -al $CROP_OUTPUT_FOLDER_NAME
# Out:
# total 24
# drwxr-xr-x 6 root root 4096 Dec  3 01:11 .
# drwxr-xr-x 6 root root 4096 Dec  3 01:11 ..
# drwxr-xr-x 2 root root 4096 Dec  3 01:11 faker
# drwxr-xr-x 2 root root 4096 Dec  3 01:11 iu
# drwxr-xr-x 2 root root 4096 Dec  3 01:11 jobs
# drwxr-xr-x 2 root root 4096 Dec  3 01:11 son

# %%
TARGET_IMAGE_PATH_NAMES = test_image_path_names

for file_name in TARGET_IMAGE_PATH_NAMES:

  # 이미지 읽기
  img=cv2.imread(file_name)

  # 모델의 입력에 맞게 변환
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # 박스 검출
  rects=dnnFaceDetector(gray,1)

  # 검출된 박스에서 left, top, right, bottom 값 구하기
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
  if right==0: continue

  # width와 height 구하기
  width=right-left
  height=bottom-top

  # 이미지 crop
  img_crop=img[top:top+height,left:left+width]

  # 저장할 파일 이름 만들기
  img_path=WORKING_PATH+'/'+CROP_OUTPUT_FOLDER_NAME+'/'+file_name.split('/')[-1].split('_')[0]+'/'+file_name.split('/')[-1]
  # crop한 이미지를 파일로 쓰기
  cv2.imwrite(img_path,img_crop)

# %% [markdown]
# 이제 다음과 같은 구조의 폴더가 생성되었다.
# Images_crop, Test_Images_crop 밑에는 얼굴부분만 crop된 이미지들이 생성되어 있다.
#
# ```
# Directory structure :
# |--Images /
# |  |-- (60 images)
# |
# |--Images_crop /
# |  |--faker
# |     |--(images)
# |  |--iu /
# |     |--(images)
# |  |--jobs /
# |     |--(imgaes)
# |
# |--Test_Images /
# |  |-- .. / (18 images)
# |
# |--Test_Images_crop /
# |  |--faker
# |     |--(images)
# |  |--iu /
# |     |--(images)
# |  |--jobs /
# |     |--(imgaes)
# |--mmod_human_face_detector.dat
# ```

# %% [markdown]
# # VGGFace 모델 로딩

# %% [markdown]
# 얼굴 피쳐 추출을 위해 VGGFace를 사용한다.
#
# https://github.com/rcmalli/keras-vggface

# %%
# !pip install keras_vggface
# Out:
# Requirement already satisfied: keras_vggface in /usr/local/lib/python3.6/dist-packages (0.6)
# Requirement already satisfied: keras in /tensorflow-1.15.2/python3.6 (from keras_vggface) (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.18.5)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.4.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (2.10.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (1.15.0)
# Requirement already satisfied: pillow in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (7.0.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from keras_vggface) (3.13)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from keras->keras_vggface) (1.1.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /tensorflow-1.15.2/python3.6 (from keras->keras_vggface) (1.0.8)

# %%
from keras_vggface.vggface import VGGFace

vgg_face_model = VGGFace(include_top=False, input_shape=(224, 224, 3))
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# Downloading data from https://github.com/rcmalli/keras-vggface/releases/download/v2.0/rcmalli_vggface_tf_notop_vgg16.h5
# 58916864/58909280 [==============================] - 2s 0us/step

# %%
vgg_face_model.summary()
# Out:
# Model: "vggface_vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1_1 (Conv2D)             (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv1_2 (Conv2D)             (None, 224, 224, 64)      36928
# _________________________________________________________________
# pool1 (MaxPooling2D)         (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2_1 (Conv2D)             (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2_2 (Conv2D)             (None, 112, 112, 128)     147584
# _________________________________________________________________
# pool2 (MaxPooling2D)         (None, 56, 56, 128)       0
# _________________________________________________________________
# conv3_1 (Conv2D)             (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv3_2 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv3_3 (Conv2D)             (None, 56, 56, 256)       590080
# _________________________________________________________________
# pool3 (MaxPooling2D)         (None, 28, 28, 256)       0
# _________________________________________________________________
# conv4_1 (Conv2D)             (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv4_2 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv4_3 (Conv2D)             (None, 28, 28, 512)       2359808
# _________________________________________________________________
# pool4 (MaxPooling2D)         (None, 14, 14, 512)       0
# _________________________________________________________________
# conv5_1 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_2 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv5_3 (Conv2D)             (None, 14, 14, 512)       2359808
# _________________________________________________________________
# pool5 (MaxPooling2D)         (None, 7, 7, 512)         0
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # 학습 데이터 로딩

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras.layers import ZeroPadding2D,Convolution2D,MaxPooling2D, Input, Flatten
from tensorflow.keras.layers import Dense,Dropout,Softmax,Flatten,Activation,BatchNormalization
from tensorflow.keras.preprocessing.image import load_img,img_to_array
from tensorflow.keras.applications.imagenet_utils import preprocess_input
import tensorflow.keras.backend as K

# %%
#Prepare Training Data
x_train=[]
y_train=[]

person_folders=os.listdir(WORKING_PATH+'/Images_crop/')
person_rep=dict()


for i,person in enumerate(person_folders):

  person_rep[i]=person

  image_names=os.listdir('Images_crop/'+person+'/')
  for image_name in image_names:
    # 이미지 로딩
    img=load_img(WORKING_PATH+'/Images_crop/'+person+'/'+image_name,target_size=(224,224))

    # numpy로 변환
    img=img_to_array(img)

    # img.shape = (224, 224, 3) -> (1, 224, 224, 3)
    img=np.expand_dims(img,axis=0)   # VGGFace는 복수의 영상을 한번에 처리한다.이에 맞도록 입력 모양 변형

    # 데이터 전처리
    img=preprocess_input(img)

    # 얼굴의 feature를 추출한다.
    img_encoded = vgg_face_model.predict(img)  # 얼굴의 feature를 추출한다.

    x_train.append(np.squeeze(K.eval(img_encoded)).tolist())
    y_train.append(i)

# %%
x_train=np.array(x_train)
y_train=np.array(y_train)

# %%
#Prepare Test Data
x_test=[]
y_test=[]
person_folders=os.listdir(WORKING_PATH+'/Test_Images_crop/')
for i,person in enumerate(person_folders):
  image_names=os.listdir('Test_Images_crop/'+person+'/')
  for image_name in image_names:
    img=load_img(WORKING_PATH+'/Test_Images_crop/'+person+'/'+image_name,target_size=(224,224))
    img=img_to_array(img)
    img=np.expand_dims(img,axis=0)
    img=preprocess_input(img)
    img_encoded = vgg_face_model.predict(img)  # 얼굴의 feature를 추출한다.
    x_test.append(np.squeeze(K.eval(img_encoded)).tolist())
    y_test.append(i)

# %%
x_test=np.array(x_test)
y_test=np.array(y_test)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (50, 7, 7, 512)
# (50,)
# (23, 7, 7, 512)
# (23,)

# %%
print(x_train.shape)
# Out:
# (50, 7, 7, 512)

# %% [markdown]
# # Face 분류 모델 정의

# %%
print(x_train.shape[1:])
# Out:
# (7, 7, 512)

# %%
classifier_model = Sequential()
classifier_model.add(Input(x_train.shape[1:])) # shape = (7, 7, 512)
classifier_model.add(Flatten())
classifier_model.add(Dense(units=100, kernel_initializer='glorot_uniform'))
classifier_model.add(BatchNormalization())
classifier_model.add(Activation('tanh'))
classifier_model.add(Dropout(0.3))
classifier_model.add(Dense(units=10, kernel_initializer='glorot_uniform'))
classifier_model.add(BatchNormalization())
classifier_model.add(Activation('tanh'))
classifier_model.add(Dropout(0.2))
classifier_model.add(Dense(units=len(person_folders), kernel_initializer='he_uniform'))
classifier_model.add(Activation('softmax'))

# %% [markdown]
# # 분류 모델 학습

# %%
classifier_model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(), optimizer='nadam',metrics=['accuracy'])

classifier_model.fit(x_train, y_train, epochs=100, validation_data=(x_test,y_test))
# Out:
# Train on 50 samples, validate on 23 samples
# Epoch 1/100
# 50/50 [==============================] - 1s 11ms/sample - loss: 1.1989 - acc: 0.4800 - val_loss: 0.2613 - val_acc: 0.9565
# Epoch 2/100
# 50/50 [==============================] - 0s 610us/sample - loss: 0.3438 - acc: 0.9600 - val_loss: 0.2052 - val_acc: 1.0000
# Epoch 3/100
# 50/50 [==============================] - 0s 536us/sample - loss: 0.3353 - acc: 0.9600 - val_loss: 0.1511 - val_acc: 1.0000
# Epoch 4/100
# 50/50 [==============================] - 0s 503us/sample - loss: 0.2577 - acc: 0.9800 - val_loss: 0.1422 - val_acc: 1.0000
# Epoch 5/100
# 50/50 [==============================] - 0s 485us/sample - loss: 0.2265 - acc: 1.0000 - val_loss: 0.1300 - val_acc: 1.0000
# Epoch 6/100
# 50/50 [==============================] - 0s 485us/sample - loss: 0.1976 - acc: 1.0000 - val_loss: 0.1243 - val_acc: 1.0000
# Epoch 7/100
# 50/50 [==============================] - 0s 510us/sample - loss: 0.1945 - acc: 1.0000 - val_loss: 0.1160 - val_acc: 1.0000
# Epoch 8/100
# 50/50 [==============================] - 0s 502us/sample - loss: 0.1958 - acc: 1.0000 - val_loss: 0.1132 - val_acc: 1.0000
# Epoch 9/100
# 50/50 [==============================] - 0s 484us/sample - loss: 0.2235 - acc: 1.0000 - val_loss: 0.1097 - val_acc: 1.0000
# Epoch 10/100
- acc: 1.0000 - val_loss: 0.0743 - val_acc: 1.0000
# Epoch 74/100
# 50/50 [==============================] - 0s 584us/sample - loss: 0.0919 - acc: 1.0000 - val_loss: 0.0766 - val_acc: 1.0000
# Epoch 75/100
# 50/50 [==============================] - 0s 552us/sample - loss: 0.0754 - acc: 1.0000 - val_loss: 0.0770 - val_acc: 1.0000
# Epoch 76/100
# 50/50 [==============================] - 0s 574us/sample - loss: 0.0907 - acc: 1.0000 - val_loss: 0.0763 - val_acc: 1.0000
# Epoch 77/100
# 50/50 [==============================] - 0s 620us/sample - loss: 0.0787 - acc: 1.0000 - val_loss: 0.0779 - val_acc: 1.0000
# Epoch 78/100
# 50/50 [==============================] - 0s 607us/sample - loss: 0.0931 - acc: 1.0000 - val_loss: 0.0780 - val_acc: 1.0000
# Epoch 79/100
# 50/50 [==============================] - 0s 557us/sample - loss: 0.0732 - acc: 1.0000 - val_loss: 0.0779 - val_acc: 1.0000
# Epoch 80/100
# 50/50 [==============================] - 0s 616us/sample - loss: 0.0650 - acc: 1.0000 - val_loss: 0.0768 - val_acc: 1.0000
# Epoch 81/100
# 50/50 [==============================] - 0s 639us/sample - loss: 0.0883 - acc: 1.0000 - val_loss: 0.0771 - val_acc: 1.0000
# Epoch 82/100
# 50/50 [==============================] - 0s 602us/sample - loss: 0.0940 - acc: 1.0000 - val_loss: 0.0773 - val_acc: 1.0000
# Epoch 83/100
# 50/50 [==============================] - 0s 564us/sample - loss: 0.0952 - acc: 1.0000 - val_loss: 0.0747 - val_acc: 1.0000
# Epoch 84/100
# 50/50 [==============================] - 0s 594us/sample - loss: 0.0746 - acc: 1.0000 - val_loss: 0.0756 - val_acc: 1.0000
# Epoch 85/100
# 50/50 [==============================] - 0s 573us/sample - loss: 0.0669 - acc: 1.0000 - val_loss: 0.0753 - val_acc: 1.0000
# Epoch 86/100
# 50/50 [==============================] - 0s 591us/sample - loss: 0.0769 - acc: 1.0000 - val_loss: 0.0745 - val_acc: 1.0000
# Epoch 87/100
# 50/50 [==============================] - 0s 636us/sample - loss: 0.1050 - acc: 1.0000 - val_loss: 0.0792 - val_acc: 1.0000
# Epoch 88/100
# 50/50 [==============================] - 0s 611us/sample - loss: 0.0964 - acc: 1.0000 - val_loss: 0.0789 - val_acc: 1.0000
# Epoch 89/100
# 50/50 [==============================] - 0s 602us/sample - loss: 0.0573 - acc: 1.0000 - val_loss: 0.0782 - val_acc: 1.0000
# Epoch 90/100
# 50/50 [==============================] - 0s 617us/sample - loss: 0.0687 - acc: 1.0000 - val_loss: 0.0770 - val_acc: 1.0000
# Epoch 91/100
# 50/50 [==============================] - 0s 504us/sample - loss: 0.0841 - acc: 1.0000 - val_loss: 0.0741 - val_acc: 1.0000
# Epoch 92/100
# 50/50 [==============================] - 0s 535us/sample - loss: 0.0712 - acc: 1.0000 - val_loss: 0.0732 - val_acc: 1.0000
# Epoch 93/100
# 50/50 [==============================] - 0s 540us/sample - loss: 0.0762 - acc: 1.0000 - val_loss: 0.0733 - val_acc: 1.0000
# Epoch 94/100
# 50/50 [==============================] - 0s 687us/sample - loss: 0.0797 - acc: 1.0000 - val_loss: 0.0711 - val_acc: 1.0000
# Epoch 95/100
# 50/50 [==============================] - 0s 524us/sample - loss: 0.0629 - acc: 1.0000 - val_loss: 0.0701 - val_acc: 1.0000
# Epoch 96/100
# 50/50 [==============================] - 0s 541us/sample - loss: 0.0466 - acc: 1.0000 - val_loss: 0.0695 - val_acc: 1.0000
# Epoch 97/100
# 50/50 [==============================] - 0s 616us/sample - loss: 0.0670 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 1.0000
# Epoch 98/100
# 50/50 [==============================] - 0s 525us/sample - loss: 0.0637 - acc: 1.0000 - val_loss: 0.0678 - val_acc: 1.0000
# Epoch 99/100
# 50/50 [==============================] - 0s 555us/sample - loss: 0.0632 - acc: 1.0000 - val_loss: 0.0686 - val_acc: 1.0000
# Epoch 100/100
# 50/50 [==============================] - 0s 547us/sample - loss: 0.0642 - acc: 1.0000 - val_loss: 0.0683 - val_acc: 1.0000

# %% [markdown]
# # 얼굴 인식 실행

# %%
def plot(img):
  plt.figure(figsize=(8,4))
  plt.imshow(img[:,:,::-1])
  plt.show()

# %%
os.mkdir(WORKING_PATH+'/Predictions')

# %%
for img_name in os.listdir(WORKING_PATH+'/Test_images/'):
  if img_name=='crop_img.jpg':
    continue
  # Load Image
  img=cv2.imread(WORKING_PATH+'/Test_images/'+img_name)
  print(WORKING_PATH+'/Test_images/'+img_name) # DEV
  gray=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

  # 얼굴 탐지
  rects=dnnFaceDetector(gray,1)
  left,top,right,bottom=0,0,0,0
  for (i,rect) in enumerate(rects):
    # Extract Each Face
    left=rect.rect.left() #x1
    top=rect.rect.top() #y1
    right=rect.rect.right() #x2
    bottom=rect.rect.bottom() #y2
    width=right-left
    height=bottom-top
    img_crop=img[top:top+height,left:left+width]
    cv2.imwrite(WORKING_PATH+'/Test_images/crop_img.jpg',img_crop)
    
    # 얼굴 영역 crop
    crop_img=load_img(WORKING_PATH+'/Test_images/crop_img.jpg',target_size=(224,224))
    crop_img=img_to_array(crop_img)
    crop_img=np.expand_dims(crop_img,axis=0)
    crop_img=preprocess_input(crop_img)
    img_encode=vgg_face_model.predict(crop_img)

    # 얼굴 영역 인식
    embed=K.eval(img_encode)
    person=classifier_model.predict(embed)
    name=person_rep[np.argmax(person)]
    os.remove(WORKING_PATH+'/Test_images/crop_img.jpg')
    cv2.rectangle(img,(left,top),(right,bottom),(0,255,0), 2)
    img=cv2.putText(img,name,(left,top-10),cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,255),2,cv2.LINE_AA)
    img=cv2.putText(img,str(np.max(person)),(right,bottom+10),cv2.FONT_HERSHEY_SIMPLEX,0.5,(0,0,255),1,cv2.LINE_AA)
  # Save images with bounding box,name and accuracy 
  cv2.imwrite(WORKING_PATH+'/Predictions/'+img_name,img)
  plot(img)
# Out:
# /content/face_data/Test_images/faker_27.jpg
# /content/face_data/Test_images/son_16.jpg
# /content/face_data/Test_images/faker_25.jpg
# /content/face_data/Test_images/iu_23.jpg
# /content/face_data/Test_images/son_18.jpg
# /content/face_data/Test_images/iu_24.jpg
# /content/face_data/Test_images/son_20.jpg
# /content/face_data/Test_images/jobs_31.jpg
# /content/face_data/Test_images/iu_33.jpg
# /content/face_data/Test_images/jobs_28.jpg
# /content/face_data/Test_images/iu_27.jpg
# /content/face_data/Test_images/faker_32.jpg
# /content/face_data/Test_images/jobs_36.jpg
# /content/face_data/Test_images/faker_29.jpg
# /content/face_data/Test_images/faker_28.jpg
# /content/face_data/Test_images/son_19.jpg
# /content/face_data/Test_images/iu_28.jpg
# /content/face_data/Test_images/iu_30.jpg
# /content/face_data/Test_images/faker_33.jpg
# /content/face_data/Test_images/jobs_32.jpg
# /content/face_data/Test_images/jobs_30.jpg
# /content/face_data/Test_images/jobs_33.jpg
# /content/face_data/Test_images/son_17.jpg
# /content/face_data/Test_images/iu_25.jpg
